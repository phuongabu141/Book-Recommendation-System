# %%
from google.colab import drive
drive.mount('/content/Mydrive')
# Out:
# Mounted at /content/Mydrive

# %%
import pandas as pd
import numpy as np
from numpy import dot
from numpy.linalg import norm
from numpy import sqrt

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %% [markdown]
# # Load data

# %%
#path = "/content/drive/MyDrive/recomment_system/Do_an/data_final/collaborative-fittering"
train = pd.read_csv("/content/Mydrive/MyDrive/recomment_system/Do_an/data_final/collaborative-fittering/final_reviews_train_than30.csv")
test = pd.read_csv("/content/Mydrive/MyDrive/recomment_system/Do_an/data_final/collaborative-fittering/final_reviews_test_than30.csv")

book_information = pd.read_csv("/content/Mydrive/MyDrive/recomment_system/Do_an/data_final/collaborative-fittering/final_books_than30.csv")

# %%
train.head()
# Out:
#          id   product_id     user_id         user_name  rating  \
# 0   6081499    3734909.0     88616.0  Trương Minh Đăng       5
# 1  12731297   14961285.0  16848626.0     Phạm Văn Tùng       5
# 2   7849857   68774130.0   8046945.0         Minh Giải       5
# 3  15666018  152449148.0   1333575.0         Genny Lee       5
# 4  17241576     655679.0  24504222.0         Nhật Việt       5
#
#                                     content  thank_count  rating_average  \
# 0                                       NaN            0             4.8
# 1                                       NaN            0             4.7
# 2                                       NaN            0             5.0
# 3  bộ truyện rất hay và giàu tính nhân văn.            0             4.9
# 4                                       NaN            0             4.9
#
#    count
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
train.shape
# Out:
# (140839, 9)

# %%
test.shape
# Out:
# (1423, 9)

# %%
book_information.shape
# Out:
# (16587, 17)

# %%
book_information.head(3)
# Out:
#                                             category  \
# 0  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
# 1  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
# 2  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
#
#                                                  url           id  \
# 0  https://tiki.vn/product-p141483251.html?spid=1...  141483251.0
# 1  https://tiki.vn/product-p125362334.html?spid=1...  125362334.0
# 2  https://tiki.vn/product-p58213080.html?spid=58...   58213080.0
#
#             sku                                               name     price  \
# 0  8.070578e+12  Sách: Thai Giáo Theo Chuyên Gia - 280 Ngày Mỗi...   80500.0
# 1  8.806987e+12  Dinh Dưỡng Thai Kỳ (Bà Bầu Ăn Gì Giúp Con Phát...  103950.0
# 2  4.467229e+12  Montessori – Phương Pháp Giáo Dục Toàn Diện Ch...   95200.0
#
#    rating_average  review_count  all_time_quantity_sold  \
# 0             5.0          58.0                   508.0
# 1             4.8          41.0                   486.0
# 2             5.0          16.0                   116.0
#
#                                          description  \
# 0  \nThai Giáo Theo Chuyên Gia, 280 Ngày, Mỗi Ngà...
# 1  “Dinh dưỡng thai kỳ” giống như một cuốn bách k...
# 2  MONTESSORI – PHƯƠNG PHÁP GIÁO DỤC TOÀN DIỆN CH...
#
#                                       specifications  seller_id    seller_sku  \
# 0  {"name": "Th\u00f4ng tin chung", "attributes":...    36846.0  3.544877e+12
# 1  {"name": "Th\u00f4ng tin chung", "attributes":...        1.0  6.946825e+12
# 2  {"name": "Th\u00f4ng tin chung", "attributes":...    53660.0  1.012848e+12
#
#        seller_name  seller_store_id  count_specification  \
# 0   Minh Long Book          36125.0                    5
# 1     Tiki Trading          40395.0                    7
# 2  Nhà sách Fahasa          51001.0                    6
#
#                                           attributes
# 0  {'id': 141483251.0, 'publisher_vn': 'Minh Long...
# 1  {'id': 125362334.0, 'publisher_vn': 'Booklife'...
# 2  {'id': 58213080.0, 'publisher_vn': '1980 Books...

# %% [markdown]
# # Một vài hàm lấy dữ liệu

# %%
def get_rating(userid, bookid):
    return (train.loc[((train.user_id== userid)&(train.product_id== bookid)), 'rating'].iloc[0])
#------------------------
def get_bookid(userid): 
    return (train.loc[(train.user_id==userid), 'product_id'].tolist())
#----------------------
def get_userid(bookid): 
    return (train.loc[(train.product_id==bookid), 'user_id'].tolist())
#------------------------
def get_book_title(bookid):
    return (book_information.loc[(book_information.id==bookid), 'name'].iloc[0])
#------------------------
def get_average_rating_user(userid):
    rating_user = train.loc[((train.user_id== userid)), 'rating']
    return np.mean(rating_user)
#-----------------------
def get_average_rating_book(bookid):
    rating_book = train.loc[((train.product_id== bookid)), 'rating']
    return np.mean(rating_book)

# %%
get_average_rating_book(58543601.0)
# Out:
# 4.826086956521739

# %%
average_rating_bookid = {}
for i in train["product_id"].unique():
    average_rating_bookid[i]=get_average_rating_book(i)

# %% [markdown]
# # Các hàm tính độ tương tự

# %% [markdown]
# ## Độ đo Cosine

# %%
def cosine_similarity_user(user1, user2):
    both_watch_count = 0
    for bookid in train.loc[train.user_id == user1, 'product_id'].to_list():
        for bookid in train.loc[train.user_id == user2, 'product_id'].tolist():
            both_watch_count +=1
    if both_watch_count == 0:
        return 0

    rating1 = []
    rating2 = []

    for bookid in train.loc[train.user_id == user1, 'product_id'].to_list():
        if bookid in train.loc[train.user_id == user2, 'product_id'].tolist():
            rating1.append(get_rating(user1, bookid))
            rating2.append(get_rating(user2, bookid))

    if (norm(rating1)*norm(rating2)) == 0:
        return 0
    return dot(rating1, rating2)/(norm(rating1)*norm(rating2))

# %%
cosine_similarity_user(12838006.0, 16635694.0)
# Out:
# 0

# %% [markdown]
# ## Độ đo tương tự Pearson

# %%
def pearson_correlation_user(user1, user2):
    both_watch_count = []
    for bookid in train.loc[(train.user_id == user1), 'product_id'].tolist():
        if bookid in train.loc[(train.user_id == user2), 'product_id'].tolist():
            both_watch_count.append(bookid)
    if len(both_watch_count) == 0:
        return 0
    rating_sum_1 = sum([get_rating(user1, bookid) for bookid in both_watch_count])
    avg_rating_sum_1 = rating_sum_1/len(both_watch_count)

    rating_sum_2 = sum([get_rating(user2, bookid) for bookid in both_watch_count])
    avg_rating_sum_2 = rating_sum_2/len(both_watch_count)

    #Gia tri tren tu
    numerator = sum([(get_rating(user1, bookid)- avg_rating_sum_1)*(get_rating(user2, bookid) - avg_rating_sum_2) for bookid in both_watch_count])
    denominator = sqrt(sum([pow((get_rating(user1, bookid) - avg_rating_sum_1), 2) for bookid in both_watch_count]))*sqrt(sum([pow((get_rating(user2, bookid) - avg_rating_sum_2), 2) for bookid in both_watch_count]))
    if denominator == 0:
        return 0
    return numerator/denominator

# %%
pearson_correlation_user(12838006.0, 16635694.0)
# Out:
# 0

# %% [markdown]
# # Hàm tính top k user có độ tương đồng

# %%
def get_similarity_user(userId, numberUser, similarityName):
    userIds = train.user_id.unique().tolist()

    if(similarityName == 'pearson'):
        similarityScoreUser = [(cosine_similarity_user(userId, useri),useri) for useri in userIds[:500] if useri != userId]
    elif(similarityName == 'cosine'):
        similarityScoreUser = [(cosine_similarity_user(userId, useri),useri) for useri in userIds[:500] if useri != userId]

    similarityScoreUser.sort(reverse=True)
    return similarityScoreUser[:numberUser]

# %%
get_similarity_user( 18393598.0	, 10, "pearson")
# Out:
# [(1.0, 27683454.0),
#  (1.0, 27018419.0),
#  (1.0, 26707397.0),
#  (1.0, 26286957.0),
#  (1.0, 25710147.0),
#  (1.0, 24304082.0),
#  (1.0, 23890467.0),
#  (1.0, 23096572.0),
#  (1.0, 22575012.0),
#  (1.0, 21979852.0)]

# %% [markdown]
# # Hàm khuyến nghị sách

# %% [markdown]
# ## Khuyến nghị dựa trên trung bình đánh giá

# %%
def get_recommendation_tbdg_user(userid, number_of_user, metric_similar):
    user_ids = train.user_id.unique().tolist()
    total = {}
    number_rating = {}
    List_similar = get_similarity_user(userid, number_of_user, metric_similar)
    for peason, user in List_similar:
        for bookid in get_bookid(user):
            if bookid not in get_bookid(userid) or get_rating(userid, bookid) == 0:
                if bookid not in total:
                    total[bookid] = 0
                    number_rating[bookid] = 0
                    total[bookid] += get_rating(user, bookid)
                    if get_rating(user, bookid) != 0:
                        number_rating[bookid] +=1
                else:
                    total[bookid] += get_rating(user, bookid)
                    if get_rating(user, bookid) != 0:
                        number_rating[bookid] +=1
                
    ranking = [(to/number_rating[bookid], bookid) for bookid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(bookid, score) for score, bookid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị dựa theo trung bình đánh giá có trọng số

# %%
def get_recommendation_tbdgcts_user(userid, number_of_user, metric_similar):
    book_ids = train.user_id.unique().tolist()
    total = {}
    similarity_sum = {}
    List_similar = get_similarity_user(userid, number_of_user, metric_similar)
    for peason, user in List_similar:
        score = peason
        for bookid in get_bookid(user):
            if bookid not in get_bookid(userid) or get_rating(userid, bookid) == 0:
                if bookid not in total:
                    total[bookid] = 0
                    total[bookid] += get_rating(user, bookid)*score
                    similarity_sum [bookid] = 0
                    similarity_sum [bookid] +=score
                else:
                    total[bookid] += get_rating(user, bookid)*score
                    similarity_sum [bookid] +=score
                
    ranking = [(to/similarity_sum[bookid], bookid) for bookid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(bookid, score) for score, bookid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị dựa trên khoảng đánh giá

# %%
def get_recommendation_kdg_user(userid, number_of_user, metric_similar):
    total = {}
    similarity_sum = {}
    List_similar = get_similarity_user(userid, number_of_user, metric_similar)
    for peason, user in List_similar:
        score = peason
        for bookid in get_bookid(user):
            if bookid not in get_bookid(userid) or get_rating(userid, bookid) == 0:
                if bookid not in total:
                    total[bookid] = 0
                    total[bookid] += (get_rating(user, bookid) - get_average_rating_user(user))*score
                    similarity_sum [bookid] = 0
                    similarity_sum [bookid] +=score
                else:
                    total[bookid] += (get_rating(user, bookid) - get_average_rating_user(user))*score
                    similarity_sum [bookid] +=score
                
    ranking = [((get_average_rating_user(userid) + to/similarity_sum[bookid]), bookid) for bookid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(userid, score) for score, userid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị sách

# %%
def get_recommendation_user(userid, number_of_user, metrics_rating, metric_similar):
    if userid not in list(train["user_id"].unique()):
        ranking = [(to, userid) for userid, to in average_rating_bookid.items()]
        ranking.sort()
        ranking.reverse()
        recomendations = [(userid, score) for score, userid in ranking]
        return recomendations
    if (metrics_rating == "tbdg"):
        recomendations = get_recommendation_tbdg_user(userid, number_of_user, metric_similar)
        return recomendations
    elif (metrics_rating == "tbdgcts"):
        recomendations = get_recommendation_tbdgcts_user(userid, number_of_user, metric_similar)
        return recomendations
    elif (metrics_rating == "kdg"):
        recomendations = get_recommendation_kdg_user(userid, number_of_user, metric_similar)
        return recomendations

# %%
# Thử nghiệm
user =  18393598.0	
number_of_user = 10
metrics_rating = "kdg" # 1 trong 3 ["tbdg", "tbdgctg", "kdg"]
metrics_similar = "cosine" # 1 trong 2 ["cosine", "peason"]
user_recommend = get_recommendation_user(user, number_of_user, metrics_rating, metrics_similar)

# %%
user_recommend
# Out:
# [(190702874.0, 5.1330049261083746),
#  (190702862.0, 5.1330049261083746),
#  (190702855.0, 5.1330049261083746),
#  (183488718.0, 5.1330049261083746),
#  (183488711.0, 5.1330049261083746),
#  (183488701.0, 5.1330049261083746),
#  (183488700.0, 5.1330049261083746),
#  (183488698.0, 5.1330049261083746),
#  (181938622.0, 5.1330049261083746),
#  (181687303.0, 5.1330049261083746),
#  (181170531.0, 5.1330049261083746),
#  (175798776.0, 5.1330049261083746),
#  (174449880.0, 5.1330049261083746),
#  (168293266.0, 5.1330049261083746),
#  (168283405.0, 5.1330049261083746),
#  (162867684.0, 5.1330049261083746),
#  (160779390.0, 5.1330049261083746),
#  (160621646.0, 5.1330049261083746),
#  (160594650.0, 5.1330049261083746),
#  (160488878.0, 5.1330049261083746),
#  (160445784.0, 5.1330049261083746),
#  (157240665.0, 5.1330049261083746),
#  (155878047.0, 5.1330049261083746),
#  (154160976.0, 5.1330049261083746),
#  (153521908.0, 5.1330049261083746),
#  (153521904.0, 5.1330049261083746),
#  (153521892.0, 5.1330049261083746),
#  (153518828.0, 5.1330049261083746),
#  (152517438.0, 5.1330049261083746),
#  (148802202.0, 5.1330049261083746),
#  (148802200.0, 5.1330049261083746),
#  (147988196.0, 5.1330049261083746),
#  (147566812.0, 5.1330049261083746),
#  (147341449.0, 5.1330049261083746),
#  (145977558.0, 5.1330049261083746),
#  (145288026.0, 5.1330049261083746),
#  (143849680.0, 5.1330049261083746),
#  (143684631.0, 5.1330049261083746),
#  (138107485.0, 5.1330049261083746),
#  (137555851.0, 5.1330049261083746),
#  (132366467.0, 5.1330049261083746),
#  (129355973.0, 5.1330049261083746),
#  (127991078.0, 5.1330049261083746),
#  (127692113.0, 5.1330049261083746),
#  (127564524.0, 5.1330049261083746),
#  (126676456.0, 5.1330049261083746),
#  (123915920.0, 5.1330049261083746),
#  (121073408.0, 5.1330049261083746),
#  (120144410.0, 5.1330049261083746),
#  (77437951.0, 4.1330049261083746),
#  (72459690.0, 4.1330049261083746),
#  (71553543.0, 4.1330049261083746),
#  (56305844.0, 4.1330049261083746),
#  (13967736.0, 4.1330049261083746),
#  (7496297.0, 4.1330049261083746),
#  (985266.0, 4.1330049261083746),
#  (719982.0, 4.1330049261083746),
#  (424141.0, 4.1330049261083746),
#  (13797248.0, 4.043478260869565),
#  (109018532.0, 4.008928571428571),
#  (142791749.0, 3.72615315718764),
#  (142833961.0, 1.1330049261083746),
#  (105483727.0, 1.1330049261083746),
#  (84651734.0, 1.1330049261083746)]

# %% [markdown]
# # Đánh giá phương pháp

# %%
def get_recommendation_4test_user(X_test, number_of_user, metrics_rating, metric_similar):
    X_test_pred = []
    X_test_userid = X_test['user_id'].tolist()
    X_test_bookid = X_test['product_id'].tolist()
    print("Dự đoán cho tập test với {} điểm dữ liệu".format(len(X_test_userid)))
    for i in range(len(X_test_userid)):
        list_R = get_recommendation_user(X_test_userid[i], number_of_user, metrics_rating, metrics_similar)
        check = 0
        for j in list_R:
            if(X_test_bookid[i] == j[0]):
                X_test_pred.append(j[1])
                check = 1
        if(check == 0 ):
            X_test_pred.append(0)
        print('----------dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
    return X_test_pred

# %% [markdown]
# ## Dự đoán và đánh giá bằng pp KDG và cosine

# %%
import time
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
test4 = test.loc[901:1423]

# %%
test4
# Out:
#             id   product_id     user_id            user_name  rating  \
# 901    9688629     525565.0  15268474.0          L c V Anina       5
# 902   14908843  122336553.0  18332421.0     Ngô Thị Như Bình       5
# 903   11206720   74285820.0  13513176.0    nguyễn mạnh khang       5
# 904   13535798   55957270.0    449766.0             Hạnh Bùi       5
# 905   17241605     686843.0  24504222.0            Nhật Việt       5
# ...        ...          ...         ...                  ...     ...
# 1418   4000207   37699900.0  17045987.0            D Trng Sn       5
# 1419   8507475   77324332.0   9789502.0          Lê Bảo Châu       5
# 1420  13504260   53452969.0   5243597.0       Võ Tô Tấn Phúc       5
# 1421  16553294  163165029.0    258281.0  phan hoàng  anh thư       5
# 1422  12772447   73787185.0  20416306.0     Nguyễn Minh Liếc       5
#
#                                                 content  thank_count  \
# 901   về hình thức: mới, còn book care đầy đủ, mua t...            0
# 902                                                 NaN            0
# 903                                                 NaN            0
# 904                                                 NaN            0
# 905                                                 NaN            0
# ...                                                 ...          ...
# 1418                                                NaN            0
# 1419                                                NaN            0
# 1420                                                NaN            2
# 1421                                                NaN            0
# 1422  Sách mới, bìa đẹp, giao hàng nhanh, nội dung đ...            0
#
#       rating_average  count
# 901              4.6      1
# 902              4.9      1
# 903              4.9      1
# 904              4.8      1
# 905              4.7      1
# ...              ...    ...
# 1418             4.6      1
# 1419             4.8      1
# 1420             4.8      1
# 1421             4.9      1
# 1422             4.8      1
#
# [522 rows x 9 columns]

# %%
import time
start = time.time()
number_similar = 100
metrics_rating = "kdg" # 1 trong 3 ["tbdg", "tbdgctg", "kdg"]
metrics_similar = "cosine" # 1 trong 2 ["cosine", "peason"]
X_test_pred_rating = get_recommendation_4test_user(test4, number_similar, metrics_rating, metrics_similar)

end = time.time()

print("Tổng thời gian dự đoán :", end - start)
# Out:
# Dự đoán cho tập test với 522 điểm dữ liệu
# ----------dự đoán cho dòng thứ 0 là 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# ----------dự đoán cho dòng thứ 1 là 5.028686111727352
# ----------dự đoán cho dòng thứ 2 là 4.919132218532085
# ----------dự đoán cho dòng thứ 3 là 3.140674994731094
# ----------dự đoán cho dòng thứ 4 là 5.0
# ----------dự đoán cho dòng thứ 5 là 5.076335877862595
# ----------dự đoán cho dòng thứ 6 là 4.887823221226973
# ----------dự đoán cho dòng thứ 7 là 4.674695459579181
# ----------dự đoán cho dòng thứ 8 là 0
# ----------dự đoán cho dòng thứ 9 là 4.9098336215636
# ----------dự đoán cho dòng thứ 10 là 5.158005332980379
# ----------dự đoán cho dòng thứ 11 là 5.026578947368421
# ----------dự đoán cho dòng thứ 12 là 4.339449541284404
# ----------dự đoán cho dòng thứ 13 là 5.079254444942477
# ----------dự đoán cho dòng thứ 14 là 4.980036297640654
# ----------dự đoán cho dòng thứ 15 là 5.007228915662651
# ----------dự đoán cho dòng thứ 16 là 0
# ----------dự đoán cho dòng thứ 17 là 0
# ----------dự đoán cho dòng thứ 18 là 4.812476832989923
# ----------dự đoán cho dòng thứ 19 là 4.886706349206349
# ----------dự đoán cho dòng thứ 20 là 0
# ----------dự đoán cho dòng thứ 21 là 0
# ----------dự đoán cho dòng thứ 22 là 5.00695381515266
# ----------dự đoán cho dòng thứ 23 là 4.614285714285714
# ----------dự đoán cho dòng thứ 24 là 0
# ----------dự đoán cho dòng thứ 25 là 4.982248420530201
# ----------dự đoán cho dòng thứ 26 là 0
# ----------dự đoán cho dòng thứ 27 là 5.008333333333333
# ----------dự đoán cho dòng thứ 28 là 5.0
# ----------dự đoán cho dòng thứ 29 là 0
# ----------dự đoán cho dòng thứ 30 là 0
# ----------dự đoán cho dòng thứ 31 là 0
# ----------dự đoán cho dòng thứ 32 là 5.062087871378825
# ----------dự đoán cho dòng thứ 33 là 4.921052631578948
# ----------dự đoán cho dòng thứ 34 là 4.916666666666667
# ----------dự đoán cho dòng thứ 35 là 0
# ----------dự đoán cho dòng thứ 36 là 3.614285714285714
# ----------dự đoán cho dòng thứ 37 là 4.978044133286069
# ----------dự đoán cho dòng thứ 38 là 5.063806293871757
# ----------dự đoán cho dòng thứ 39 là 4.959803921568628
# ----------dự đoán cho dòng thứ 40 là 5.171597633136095
# ----------dự đoán cho dòng thứ 41 là 4.414310370344853
# ----------dự đoán cho dòng thứ 42 là 0
# ----------dự đoán cho dòng thứ 43 là 5.008928571428571
# ----------dự đoán cho dòng thứ 44 là 0
# ----------dự đoán cho dòng thứ 45 là 4.8027277734993365
# ----------dự đoán cho dòng thứ 46 là 5.085499801195985
# ----------dự đoán cho dòng thứ 47 là 5.093158806820649
# ----------dự đoán cho dòng thứ 48 là 5.017942176870748
# ----------dự đoán cho dòng thứ 49 là 5.064516129032258
# ----------dự đoán cho dòng thứ 50 là 0
# ----------dự đoán cho dòng thứ 51 là 5.040748559137778
# ----------dự đoán cho dòng thứ 52 là 5.496012759170654
# ----------dự đoán cho dòng thứ 53 là 4.988244514106583
# ----------dự đoán cho dòng thứ 54 là 4.684780537381694
# ----------dự đoán cho dòng thứ 55 là 0
# ----------dự đoán cho dòng thứ 56 là 0
# ----------dự đoán cho dòng thứ 57 là 4.898886901814556
# ----------dự đoán cho dòng thứ 58 là 5.309523809523809
# ----------dự đoán cho dòng thứ 59 là 5.05493385051069
# ----------dự đoán cho dòng thứ 60 là 4.923076923076923
# ----------dự đoán cho dòng thứ 61 là 5.05784144578019
# ----------dự đoán cho dòng thứ 62 là 4.048426630869661
# ----------dự đoán cho dòng thứ 63 là 5.0
# ----------dự đoán cho dòng thứ 64 là 4.806451612903226
# ----------dự đoán cho dòng thứ 65 là 5.0
# ----------dự đoán cho dòng thứ 66 là 5.021326533510226
# ----------dự đoán cho dòng thứ 67 là 4.991150442477876
# ----------dự đoán cho dòng thứ 68 là 5.035002507912898
# ----------dự đoán cho dòng thứ 69 là 0
# ----------dự đoán cho dòng thứ 70 là 5.0
# ----------dự đoán cho dòng thứ 71 là 5.055344754787141
# ----------dự đoán cho dòng thứ 72 là 5.0
# ----------dự đoán cho dòng thứ 73 là 0
# ----------dự đoán cho dòng thứ 74 là 0
# ----------dự đoán cho dòng thứ 75 là 4.956544293695131
# ----------dự đoán cho dòng thứ 76 là 4.982214746852585
# ----------dự đoán cho dòng thứ 77 là 4.981308411214953
# ----------dự đoán cho dòng thứ 78 là 5.00501239811786
# ----------dự đoán cho dòng thứ 79 là 4.945945945945946
# ----------dự đoán cho dòng thứ 80 là 5.058917039698141
# ----------dự đoán cho dòng thứ 81 là 0
# ----------dự đoán cho dòng thứ 82 là 0
# ----------dự đoán cho dòng thứ 83 là 4.964904420549582
# ----------dự đoán cho dòng thứ 84 là 0
# ----------dự đoán cho dòng thứ 85 là 0
# ----------dự đoán cho dòng thứ 86 là 5.088859416445623
# ----------dự đoán cho dòng thứ 87 là 4.805147058823529
# ----------dự đoán cho dòng thứ 88 là 0
# ----------dự đoán cho dòng thứ 89 là 0
# ----------dự đoán cho dòng thứ 90 là 0
# ----------dự đoán cho dòng thứ 91 là 4.470250081459759
# ----------dự đoán cho dòng thứ 92 là 5.0372050330453835
# ----------dự đoán cho dòng thứ 93 là 4.55913298552735
# ----------dự đoán cho dòng thứ 94 là 4.389522451888809
# ----------dự đoán cho dòng thứ 95 là 4.970588235294118
# ----------dự đoán cho dòng thứ 96 là 0
# ----------dự đoán cho dòng thứ 97 là 4.694331733340848
# ----------dự đoán cho dòng thứ 98 là 0
# ----------dự đoán cho dòng thứ 99 là 0
# ----------dự đoán cho dòng thứ 100 là 3.8188659436430297
# ----------dự đoán cho dòng thứ 101 là 0
# ----------dự đoán cho dòng thứ 102 là 5.139670736638611
# ----------dự đoán cho dòng thứ 103 là 5.021163618937243
# ----------dự đoán cho dòng thứ 104 là 0
# ----------dự đoán cho dòng thứ 105 là 5.019676870748299
# ----------dự đoán cho dòng thứ 106 là 0
# ----------dự đoán cho dòng thứ 107 là 0
# ----------dự đoán cho dòng thứ 108 là 0
# ----------dự đoán cho dòng thứ 109 là 4.024399007781974
# ----------dự đoán cho dòng thứ 110 là 0
# ----------dự đoán cho dòng thứ 111 là 4.976664398176339
# ----------dự đoán cho dòng thứ 112 là 3.937135792049883
# ----------dự đoán cho dòng thứ 113 là 5.055944055944056
# ----------dự đoán cho dòng thứ 114 là 0
# ----------dự đoán cho dòng thứ 115 là 4.928702444639911
# ----------dự đoán cho dòng thứ 116 là 5.036902234844446
# ----------dự đoán cho dòng thứ 117 là 0
# ----------dự đoán cho dòng thứ 118 là 5.2631578947368425
# ----------dự đoán cho dòng thứ 119 là 5.0
# ----------dự đoán cho dòng thứ 120 là 0
# ----------dự đoán cho dòng thứ 121 là 5.181078455185815
# ----------dự đoán cho dòng thứ 122 là 4.999564692750469
# ----------dự đoán cho dòng thứ 123 là 0
# ----------dự đoán cho dòng thứ 124 là 4.5838715454254935
# ----------dự đoán cho dòng thứ 125 là 0
# ----------dự đoán cho dòng thứ 126 là 5.054421768707483
# ----------dự đoán cho dòng thứ 127 là 4.928571428571429
# ----------dự đoán cho dòng thứ 128 là 5.008710108196157
# ----------dự đoán cho dòng thứ 129 là 4.8413293353323335
# ----------dự đoán cho dòng thứ 130 là 4.808052321376512
# ----------dự đoán cho dòng thứ 131 là 4.9697989925393635
# ----------dự đoán cho dòng thứ 132 là 4.622972972972972
# ----------dự đoán cho dòng thứ 133 là 5.0038167938931295
# ----------dự đoán cho dòng thứ 134 là 4.349052631578948
# ----------dự đoán cho dòng thứ 135 là 4.942270437814801
# ----------dự đoán cho dòng thứ 136 là 5.0044716329799455
# ----------dự đoán cho dòng thứ 137 là 5.0285714285714285
# ----------dự đoán cho dòng thứ 138 là 0
# ----------dự đoán cho dòng thứ 139 là 0
# ----------dự đoán cho dòng thứ 140 là 4.585841708783832
# ----------dự đoán cho dòng thứ 141 là 0
# ----------dự đoán cho dòng thứ 142 là 5.076416157610831
# ----------dự đoán cho dòng thứ 143 là 0
# ----------dự đoán cho dòng thứ 144 là 4.984298665201641
# ----------dự đoán cho dòng thứ 145 là 5.0
# ----------dự đoán cho dòng thứ 146 là 4.818090017442478
# ----------dự đoán cho dòng thứ 147 là 5.0078088578088575
# ----------dự đoán cho dòng thứ 148 là 0
# ----------dự đoán cho dòng thứ 149 là 0
# ----------dự đoán cho dòng thứ 150 là 0
# ----------dự đoán cho dòng thứ 151 là 4.200158730158731
# ----------dự đoán cho dòng thứ 152 là 0
# ----------dự đoán cho dòng thứ 153 là 4.86
# ----------dự đoán cho dòng thứ 154 là 4.366666666666666
# ----------dự đoán cho dòng thứ 155 là 0
# ----------dự đoán cho dòng thứ 156 là 0
# ----------dự đoán cho dòng thứ 157 là 0
# ----------dự đoán cho dòng thứ 158 là 4.433856329795416
# ----------dự đoán cho dòng thứ 159 là 0
# ----------dự đoán cho dòng thứ 160 là 4.162020118679078
# ----------dự đoán cho dòng thứ 161 là 5.043682795698925
# ----------dự đoán cho dòng thứ 162 là 0
# ----------dự đoán cho dòng thứ 163 là 4.882179487179487
# ----------dự đoán cho dòng thứ 164 là 5.0667408231368185
# ----------dự đoán cho dòng thứ 165 là 5.074762030065042
# ----------dự đoán cho dòng thứ 166 là 0
# ----------dự đoán cho dòng thứ 167 là 4.254427088276046
# ----------dự đoán cho dòng thứ 168 là 0
# ----------dự đoán cho dòng thứ 169 là 5.0
# ----------dự đoán cho dòng thứ 170 là 0
# ----------dự đoán cho dòng thứ 171 là 5.272671568627451
# ----------dự đoán cho dòng thứ 172 là 0
# ----------dự đoán cho dòng thứ 173 là 5.596446700507614
# ----------dự đoán cho dòng thứ 174 là 0
# ----------dự đoán cho dòng thứ 175 là 5.018072289156627
# ----------dự đoán cho dòng thứ 176 là 0
# ----------dự đoán cho dòng thứ 177 là 5.010250502185986
# ----------dự đoán cho dòng thứ 178 là 4.902621773038326
# ----------dự đoán cho dòng thứ 179 là 4.7182928000627635
# ----------dự đoán cho dòng thứ 180 là 0
# ----------dự đoán cho dòng thứ 181 là 4.740820108370479
# ----------dự đoán cho dòng thứ 182 là 4.721604261908605
# ----------dự đoán cho dòng thứ 183 là 5.048973880597015
# ----------dự đoán cho dòng thứ 184 là 5.033215252415333
# ----------dự đoán cho dòng thứ 185 là 4.996141975308642
# ----------dự đoán cho dòng thứ 186 là 5.305608465608466
# ----------dự đoán cho dòng thứ 187 là 0
# ----------dự đoán cho dòng thứ 188 là 0
# ----------dự đoán cho dòng thứ 189 là 5.053725905328833
# ----------dự đoán cho dòng thứ 190 là 3.8260869565217392
# ----------dự đoán cho dòng thứ 191 là 5.081261425049429
# ----------dự đoán cho dòng thứ 192 là 0
# ----------dự đoán cho dòng thứ 193 là 4.976771196283392
# ----------dự đoán cho dòng thứ 194 là 4.905950404932146
# ----------dự đoán cho dòng thứ 195 là 0
# ----------dự đoán cho dòng thứ 196 là 0
# ----------dự đoán cho dòng thứ 197 là 0
# ----------dự đoán cho dòng thứ 198 là 5.021464646464647
# ----------dự đoán cho dòng thứ 199 là 5.106025595449697
# ----------dự đoán cho dòng thứ 200 là 0
# ----------dự đoán cho dòng thứ 201 là 0
# ----------dự đoán cho dòng thứ 202 là 4.942330241978468
# ----------dự đoán cho dòng thứ 203 là 0
# ----------dự đoán cho dòng thứ 204 là 0
# ----------dự đoán cho dòng thứ 205 là 4.8344131470351375
# ----------dự đoán cho dòng thứ 206 là 0
# ----------dự đoán cho dòng thứ 207 là 5.05046235046235
# ----------dự đoán cho dòng thứ 208 là 4.909311026394464
# ----------dự đoán cho dòng thứ 209 là 3.5743726021278253
# ----------dự đoán cho dòng thứ 210 là 5.001855317025596
# ----------dự đoán cho dòng thứ 211 là 4.697986577181208
# ----------dự đoán cho dòng thứ 212 là 4.962264150943396
# ----------dự đoán cho dòng thứ 213 là 5.0
# ----------dự đoán cho dòng thứ 214 là 4.970971934351267
# ----------dự đoán cho dòng thứ 215 là 0
# ----------dự đoán cho dòng thứ 216 là 4.816399286987522
# ----------dự đoán cho dòng thứ 217 là 4.508818440242244
# ----------dự đoán cho dòng thứ 218 là 0
# ----------dự đoán cho dòng thứ 219 là 4.954887218045113
# ----------dự đoán cho dòng thứ 220 là 4.980344731720878
# ----------dự đoán cho dòng thứ 221 là 0
# ----------dự đoán cho dòng thứ 222 là 5.022988505747127
# ----------dự đoán cho dòng thứ 223 là 4.823792023579258
# ----------dự đoán cho dòng thứ 224 là 0
# ----------dự đoán cho dòng thứ 225 là 4.514102564102565
# ----------dự đoán cho dòng thứ 226 là 4.971770334928229
# ----------dự đoán cho dòng thứ 227 là 5.026044836680868
# ----------dự đoán cho dòng thứ 228 là 5.053989146949444
# ----------dự đoán cho dòng thứ 229 là 5.1317198543585345
# ----------dự đoán cho dòng thứ 230 là 0
# ----------dự đoán cho dòng thứ 231 là 5.0
# ----------dự đoán cho dòng thứ 232 là 4.990656724648058
# ----------dự đoán cho dòng thứ 233 là 5.0
# ----------dự đoán cho dòng thứ 234 là 4.717391304347826
# ----------dự đoán cho dòng thứ 235 là 5.080510763782082
# ----------dự đoán cho dòng thứ 236 là 0
# ----------dự đoán cho dòng thứ 237 là 5.078734889543115
# ----------dự đoán cho dòng thứ 238 là 0
# ----------dự đoán cho dòng thứ 239 là 0
# ----------dự đoán cho dòng thứ 240 là 0
# ----------dự đoán cho dòng thứ 241 là 5.205645161290322
# ----------dự đoán cho dòng thứ 242 là 4.980328667072428
# ----------dự đoán cho dòng thứ 243 là 0
# ----------dự đoán cho dòng thứ 244 là 5.076152683295541
# ----------dự đoán cho dòng thứ 245 là 5.002744656421127
# ----------dự đoán cho dòng thứ 246 là 0
# ----------dự đoán cho dòng thứ 247 là 0
# ----------dự đoán cho dòng thứ 248 là 5.002986306221514
# ----------dự đoán cho dòng thứ 249 là 5.296446700507614
# ----------dự đoán cho dòng thứ 250 là 5.0272108843537415
# ----------dự đoán cho dòng thứ 251 là 0
# ----------dự đoán cho dòng thứ 252 là 0
# ----------dự đoán cho dòng thứ 253 là 0
# ----------dự đoán cho dòng thứ 254 là 5.503663003663004
# ----------dự đoán cho dòng thứ 255 là 5.0
# ----------dự đoán cho dòng thứ 256 là 4.547985347985348
# ----------dự đoán cho dòng thứ 257 là 0
# ----------dự đoán cho dòng thứ 258 là 0
# ----------dự đoán cho dòng thứ 259 là 0
# ----------dự đoán cho dòng thứ 260 là 5.014761646803899
# ----------dự đoán cho dòng thứ 261 là 4.999606124698019
# ----------dự đoán cho dòng thứ 262 là 5.038167938931298
# ----------dự đoán cho dòng thứ 263 là 4.776470588235294
# ----------dự đoán cho dòng thứ 264 là 4.4591532498509245
# ----------dự đoán cho dòng thứ 265 là 5.039473684210526
# ----------dự đoán cho dòng thứ 266 là 0
# ----------dự đoán cho dòng thứ 267 là 4.611424910034026
# ----------dự đoán cho dòng thứ 268 là 5.0
# ----------dự đoán cho dòng thứ 269 là 2.615926476142515
# ----------dự đoán cho dòng thứ 270 là 4.903291958985429
# ----------dự đoán cho dòng thứ 271 là 0
# ----------dự đoán cho dòng thứ 272 là 4.125429168532617
# ----------dự đoán cho dòng thứ 273 là 4.757929128506991
# ----------dự đoán cho dòng thứ 274 là 0
# ----------dự đoán cho dòng thứ 275 là 4.85
# ----------dự đoán cho dòng thứ 276 là 4.968781267522037
# ----------dự đoán cho dòng thứ 277 là 4.943564993564993
# ----------dự đoán cho dòng thứ 278 là 4.767104294475841
# ----------dự đoán cho dòng thứ 279 là 4.849378736211056
# ----------dự đoán cho dòng thứ 280 là 4.715249005380585
# ----------dự đoán cho dòng thứ 281 là 5.040229885057471
# ----------dự đoán cho dòng thứ 282 là 0
# ----------dự đoán cho dòng thứ 283 là 5.0
# ----------dự đoán cho dòng thứ 284 là 0
# ----------dự đoán cho dòng thứ 285 là 0
# ----------dự đoán cho dòng thứ 286 là 0
# ----------dự đoán cho dòng thứ 287 là 5.0
# ----------dự đoán cho dòng thứ 288 là 0
# ----------dự đoán cho dòng thứ 289 là 0
# ----------dự đoán cho dòng thứ 290 là 4.96152966530325
# ----------dự đoán cho dòng thứ 291 là 0
# ----------dự đoán cho dòng thứ 292 là 4.857142857142857
# ----------dự đoán cho dòng thứ 293 là 4.900122930282374
# ----------dự đoán cho dòng thứ 294 là 0
# ----------dự đoán cho dòng thứ 295 là 4.8545454545454545
# ----------dự đoán cho dòng thứ 296 là 4.831146752515835
# ----------dự đoán cho dòng thứ 297 là 4.781463502337289
# ----------dự đoán cho dòng thứ 298 là 4.9891826923076925
# ----------dự đoán cho dòng thứ 299 là 0
# ----------dự đoán cho dòng thứ 300 là 5.0
# ----------dự đoán cho dòng thứ 301 là 5.13927815970386
# ----------dự đoán cho dòng thứ 302 là 0
# ----------dự đoán cho dòng thứ 303 là 5.005190205776394
# ----------dự đoán cho dòng thứ 304 là 4.846628653579061
# ----------dự đoán cho dòng thứ 305 là 0
# ----------dự đoán cho dòng thứ 306 là 0
# ----------dự đoán cho dòng thứ 307 là 5.007017543859649
# ----------dự đoán cho dòng thứ 308 là 5.053333333333334
# ----------dự đoán cho dòng thứ 309 là 4.964285714285714
# ----------dự đoán cho dòng thứ 310 là 0
# ----------dự đoán cho dòng thứ 311 là 4.805150700438658
# ----------dự đoán cho dòng thứ 312 là 4.993679462429462
# ----------dự đoán cho dòng thứ 313 là 0
# ----------dự đoán cho dòng thứ 314 là 5.4125874125874125
# ----------dự đoán cho dòng thứ 315 là 5.02
# ----------dự đoán cho dòng thứ 316 là 0
# ----------dự đoán cho dòng thứ 317 là 4.518007645900116
# ----------dự đoán cho dòng thứ 318 là 0
# ----------dự đoán cho dòng thứ 319 là 4.7708611234622795
# ----------dự đoán cho dòng thứ 320 là 4.947399181765049
# ----------dự đoán cho dòng thứ 321 là 4.56183558746591
# ----------dự đoán cho dòng thứ 322 là 4.66061659038497
# ----------dự đoán cho dòng thứ 323 là 5.011363636363637
# ----------dự đoán cho dòng thứ 324 là 4.9610679875562536
# ----------dự đoán cho dòng thứ 325 là 5.038929677131924
# ----------dự đoán cho dòng thứ 326 là 0
# ----------dự đoán cho dòng thứ 327 là 0
# ----------dự đoán cho dòng thứ 328 là 5.004694835680751
# ----------dự đoán cho dòng thứ 329 là 4.572648916197303
# ----------dự đoán cho dòng thứ 330 là 5.010334351541669
# ----------dự đoán cho dòng thứ 331 là 4.865108716070254
# ----------dự đoán cho dòng thứ 332 là 0
# ----------dự đoán cho dòng thứ 333 là 0
# ----------dự đoán cho dòng thứ 334 là 5.008849557522124
# ----------dự đoán cho dòng thứ 335 là 5.196101952216
# ----------dự đoán cho dòng thứ 336 là 5.004347826086956
# ----------dự đoán cho dòng thứ 337 là 4.84856900750201
# ----------dự đoán cho dòng thứ 338 là 0
# ----------dự đoán cho dòng thứ 339 là nan
# ----------dự đoán cho dòng thứ 340 là 4.983870967741935
# ----------dự đoán cho dòng thứ 341 là 5.065019539284245
# ----------dự đoán cho dòng thứ 342 là 0
# ----------dự đoán cho dòng thứ 343 là 5.00763358778626
# ----------dự đoán cho dòng thứ 344 là 5.096159176928408
# ----------dự đoán cho dòng thứ 345 là 5.007893514935768
# ----------dự đoán cho dòng thứ 346 là 5.015873015873016
# ----------dự đoán cho dòng thứ 347 là 4.765475720786224
# ----------dự đoán cho dòng thứ 348 là 5.0272108843537415
# ----------dự đoán cho dòng thứ 349 là 0
# ----------dự đoán cho dòng thứ 350 là 0
# ----------dự đoán cho dòng thứ 351 là 5.027027027027027
# ----------dự đoán cho dòng thứ 352 là 0
# ----------dự đoán cho dòng thứ 353 là 4.959781056639695
# ----------dự đoán cho dòng thứ 354 là 0
# ----------dự đoán cho dòng thứ 355 là 0
# ----------dự đoán cho dòng thứ 356 là 5.0606589063110805
# ----------dự đoán cho dòng thứ 357 là 0
# ----------dự đoán cho dòng thứ 358 là 0
# ----------dự đoán cho dòng thứ 359 là 3.973889088177925
# ----------dự đoán cho dòng thứ 360 là 4.842284885780651
# ----------dự đoán cho dòng thứ 361 là 0
# ----------dự đoán cho dòng thứ 362 là 4.619959677419355
# ----------dự đoán cho dòng thứ 363 là 4.7729312045129175
# ----------dự đoán cho dòng thứ 364 là 0
# ----------dự đoán cho dòng thứ 365 là 0
# ----------dự đoán cho dòng thứ 366 là 0
# ----------dự đoán cho dòng thứ 367 là 4.027859038951189
# ----------dự đoán cho dòng thứ 368 là 4.8987048030221265
# ----------dự đoán cho dòng thứ 369 là 4.986026594545864
# ----------dự đoán cho dòng thứ 370 là 0
# ----------dự đoán cho dòng thứ 371 là 0
# ----------dự đoán cho dòng thứ 372 là 4.306887418993322
# ----------dự đoán cho dòng thứ 373 là 0
# ----------dự đoán cho dòng thứ 374 là 5.0081449026979215
# ----------dự đoán cho dòng thứ 375 là 5.0351348702534064
# ----------dự đoán cho dòng thứ 376 là 0
# ----------dự đoán cho dòng thứ 377 là 0
# ----------dự đoán cho dòng thứ 378 là 0
# ----------dự đoán cho dòng thứ 379 là 4.886954177897574
# ----------dự đoán cho dòng thứ 380 là 0
# ----------dự đoán cho dòng thứ 381 là 4.738027009518941
# ----------dự đoán cho dòng thứ 382 là 0
# ----------dự đoán cho dòng thứ 383 là 4.90666720623955
# ----------dự đoán cho dòng thứ 384 là 0
# ----------dự đoán cho dòng thứ 385 là 5.042465891570919
# ----------dự đoán cho dòng thứ 386 là 5.031217750257998
# ----------dự đoán cho dòng thứ 387 là 4.9375
# ----------dự đoán cho dòng thứ 388 là 5.035078970894335
# ----------dự đoán cho dòng thứ 389 là 0
# ----------dự đoán cho dòng thứ 390 là 0
# ----------dự đoán cho dòng thứ 391 là 5.0
# ----------dự đoán cho dòng thứ 392 là 0
# ----------dự đoán cho dòng thứ 393 là 0
# ----------dự đoán cho dòng thứ 394 là 0
# ----------dự đoán cho dòng thứ 395 là 0
# ----------dự đoán cho dòng thứ 396 là 0
# ----------dự đoán cho dòng thứ 397 là 0
# ----------dự đoán cho dòng thứ 398 là 0
# ----------dự đoán cho dòng thứ 399 là 5.018492960869083
# ----------dự đoán cho dòng thứ 400 là 0
# ----------dự đoán cho dòng thứ 401 là 4.994741711421257
# ----------dự đoán cho dòng thứ 402 là 4.702702702702703
# ----------dự đoán cho dòng thứ 403 là 4.829461722691584
# ----------dự đoán cho dòng thứ 404 là 4.986957106360092
# ----------dự đoán cho dòng thứ 405 là 5.078746650175222
# ----------dự đoán cho dòng thứ 406 là 5.045235068441308
# ----------dự đoán cho dòng thứ 407 là 0
# ----------dự đoán cho dòng thứ 408 là 0
# ----------dự đoán cho dòng thứ 409 là 4.54626801005338
# ----------dự đoán cho dòng thứ 410 là 0
# ----------dự đoán cho dòng thứ 411 là 0
# ----------dự đoán cho dòng thứ 412 là 4.970902973080814
# ----------dự đoán cho dòng thứ 413 là 4.9523809523809526
# ----------dự đoán cho dòng thứ 414 là 5.118101138095656
# ----------dự đoán cho dòng thứ 415 là 4.631038786829674
# ----------dự đoán cho dòng thứ 416 là 5.13338122605364
# ----------dự đoán cho dòng thứ 417 là 5.077330677678916
# ----------dự đoán cho dòng thứ 418 là 0
# ----------dự đoán cho dòng thứ 419 là 4.5480374151897545
# ----------dự đoán cho dòng thứ 420 là 0
# ----------dự đoán cho dòng thứ 421 là 5.193974850494685
# ----------dự đoán cho dòng thứ 422 là 0
# ----------dự đoán cho dòng thứ 423 là 4.5455933682373475
# ----------dự đoán cho dòng thứ 424 là 4.623079877112135
# ----------dự đoán cho dòng thứ 425 là 4.827010523580616
# ----------dự đoán cho dòng thứ 426 là 4.960282641484687
# ----------dự đoán cho dòng thứ 427 là 0
# ----------dự đoán cho dòng thứ 428 là 4.998298644390662
# ----------dự đoán cho dòng thứ 429 là 4.966666666666667
# ----------dự đoán cho dòng thứ 430 là 0
# ----------dự đoán cho dòng thứ 431 là 0
# ----------dự đoán cho dòng thứ 432 là 5.075489727663641
# ----------dự đoán cho dòng thứ 433 là 4.484742550492958
# ----------dự đoán cho dòng thứ 434 là 0
# ----------dự đoán cho dòng thứ 435 là 5.015957698215763
# ----------dự đoán cho dòng thứ 436 là 0
# ----------dự đoán cho dòng thứ 437 là 5.021784037558685
# ----------dự đoán cho dòng thứ 438 là 4.811506202589327
# ----------dự đoán cho dòng thứ 439 là 5.020821485937765
# ----------dự đoán cho dòng thứ 440 là 5.008695652173913
# ----------dự đoán cho dòng thứ 441 là 0
# ----------dự đoán cho dòng thứ 442 là 4.4675777981555065
# ----------dự đoán cho dòng thứ 443 là 4.908450704225352
# ----------dự đoán cho dòng thứ 444 là 0
# ----------dự đoán cho dòng thứ 445 là 4.705056398366033
# ----------dự đoán cho dòng thứ 446 là 0
# ----------dự đoán cho dòng thứ 447 là 5.036682132752702
# ----------dự đoán cho dòng thứ 448 là 0
# ----------dự đoán cho dòng thứ 449 là 4.91476903057905
# ----------dự đoán cho dòng thứ 450 là 4.7990176490176495
# ----------dự đoán cho dòng thứ 451 là 0
# ----------dự đoán cho dòng thứ 452 là 5.041065873009966
# ----------dự đoán cho dòng thứ 453 là 0
# ----------dự đoán cho dòng thứ 454 là 5.030784061635661
# ----------dự đoán cho dòng thứ 455 là 0
# ----------dự đoán cho dòng thứ 456 là 4.966507177033494
# ----------dự đoán cho dòng thứ 457 là 4.224901816773478
# ----------dự đoán cho dòng thứ 458 là 0
# ----------dự đoán cho dòng thứ 459 là 5.0
# ----------dự đoán cho dòng thứ 460 là 4.83106404307393
# ----------dự đoán cho dòng thứ 461 là 0
# ----------dự đoán cho dòng thứ 462 là 4.9581081081081075
# ----------dự đoán cho dòng thứ 463 là 0
# ----------dự đoán cho dòng thứ 464 là 5.074014337986123
# ----------dự đoán cho dòng thứ 465 là 0
# ----------dự đoán cho dòng thứ 466 là 5.202346508091859
# ----------dự đoán cho dòng thứ 467 là 5.020202020202021
# ----------dự đoán cho dòng thứ 468 là 4.7985134362990545
# ----------dự đoán cho dòng thứ 469 là 4.998037559909788
# ----------dự đoán cho dòng thứ 470 là 0
# ----------dự đoán cho dòng thứ 471 là 4.964282235802222
# ----------dự đoán cho dòng thứ 472 là 0
# ----------dự đoán cho dòng thứ 473 là 0
# ----------dự đoán cho dòng thứ 474 là 5.018072289156627
# ----------dự đoán cho dòng thứ 475 là 5.016863843918639
# ----------dự đoán cho dòng thứ 476 là 4.622224911044787
# ----------dự đoán cho dòng thứ 477 là 4.971831190533779
# ----------dự đoán cho dòng thứ 478 là 5.051181728792348
# ----------dự đoán cho dòng thứ 479 là 4.97561825148032
# ----------dự đoán cho dòng thứ 480 là 4.419494541078959
# ----------dự đoán cho dòng thứ 481 là 4.971098265895954
# ----------dự đoán cho dòng thứ 482 là 4.5935
# ----------dự đoán cho dòng thứ 483 là 5.058540723981901
# ----------dự đoán cho dòng thứ 484 là 4.8242846975106115
# ----------dự đoán cho dòng thứ 485 là 0
# ----------dự đoán cho dòng thứ 486 là 4.707681365576103
# ----------dự đoán cho dòng thứ 487 là 5.066539641098682
# ----------dự đoán cho dòng thứ 488 là 4.887652670251155
# ----------dự đoán cho dòng thứ 489 là 0
# ----------dự đoán cho dòng thứ 490 là 4.896192938595036
# ----------dự đoán cho dòng thứ 491 là 4.9300665456745305
# ----------dự đoán cho dòng thứ 492 là 5.034030238012075
# ----------dự đoán cho dòng thứ 493 là 5.119291131794295
# ----------dự đoán cho dòng thứ 494 là 0
# ----------dự đoán cho dòng thứ 495 là 0
# ----------dự đoán cho dòng thứ 496 là 5.01489644328779
# ----------dự đoán cho dòng thứ 497 là 0
# ----------dự đoán cho dòng thứ 498 là 5.071900220102715
# ----------dự đoán cho dòng thứ 499 là 4.537750732476899
# ----------dự đoán cho dòng thứ 500 là 4.96875
# ----------dự đoán cho dòng thứ 501 là 4.962323037323038
# ----------dự đoán cho dòng thứ 502 là 4.984134248665141
# ----------dự đoán cho dòng thứ 503 là 4.981721981721982
# ----------dự đoán cho dòng thứ 504 là 4.9743589743589745
# ----------dự đoán cho dòng thứ 505 là 4.991869918699187
# ----------dự đoán cho dòng thứ 506 là 5.0
# ----------dự đoán cho dòng thứ 507 là 0
# ----------dự đoán cho dòng thứ 508 là 5.172727272727273
# ----------dự đoán cho dòng thứ 509 là 0
# ----------dự đoán cho dòng thứ 510 là 0
# ----------dự đoán cho dòng thứ 511 là 0
# ----------dự đoán cho dòng thứ 512 là 4.873436154488786
# ----------dự đoán cho dòng thứ 513 là 5.011513157894737
# ----------dự đoán cho dòng thứ 514 là 0
# ----------dự đoán cho dòng thứ 515 là 5.019609855927097
# ----------dự đoán cho dòng thứ 516 là 0
# ----------dự đoán cho dòng thứ 517 là 0
# ----------dự đoán cho dòng thứ 518 là 0
# ----------dự đoán cho dòng thứ 519 là 5.070430107526882
# ----------dự đoán cho dòng thứ 520 là 4.862068965517241
# ----------dự đoán cho dòng thứ 521 là 0
# Tổng thời gian dự đoán : 18722.321276426315

# %%
import csv
X_test_pred_rating1= pd.DataFrame(data=X_test_pred_rating)
#X_test_pred_rating1 = X_test_pred_rating
X_test_pred_rating1.to_csv('/content/Mydrive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/CF_User_Based/Pre-KDG-Cosine-901-1422.csv',header=True, index = None)

# %%
X_test_pred_rating = list(np.where(np.isnan(X_test_pred_rating), 0, X_test_pred_rating))

X_test_pred_rating_select = []
X_test_true_rating_select = []

for i in range(len(X_test_pred_rating)):
    if (X_test_pred_rating[i] != 0):
        X_test_pred_rating_select.append(X_test_pred_rating[i])
        X_test_true_rating_select.append(test['rating'].tolist()[i])
        X_test_pred_rating_select_round = [np.round(num) for num in X_test_pred_rating_select]

mse = mean_squared_error(X_test_true_rating_select, X_test_pred_rating_select)
rmse = math.sqrt(mse)
mae = mean_absolute_error(X_test_true_rating_select, X_test_pred_rating_select)

X_test_true_rating_select.sort(reverse = True)
max = X_test_true_rating_select[0]
min = X_test_true_rating_select[len(X_test_true_rating_select)-1]
nmae = mae/(max-min)
print('---------------------------------')
print('Đánh giá trên độ đo MSE:', mse)
print('Đánh giá trên độ đo RMSE:', rmse)
print('Đánh giá trên độ đo MAE:', mae)
print('Đánh giá trên độ đo NMAE:', nmae)
