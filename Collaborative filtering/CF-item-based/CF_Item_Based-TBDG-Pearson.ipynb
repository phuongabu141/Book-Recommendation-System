# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from numpy import dot
from numpy.linalg import norm
from numpy import sqrt

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %% [markdown]
# # Load data

# %%
train = pd.read_csv("/content/drive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/Data/data-collaborative-fittering/final_reviews_train_than30.csv")
test = pd.read_csv("/content/drive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/Data/data-collaborative-fittering/final_reviews_test_than30.csv")

book_information = pd.read_csv("/content/drive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/Data/data-collaborative-fittering/final_books_than30.csv")

# %%
train.head()
# Out:
#          id   product_id     user_id         user_name  rating  \
# 0   6081499    3734909.0     88616.0  Trương Minh Đăng       5
# 1  12731297   14961285.0  16848626.0     Phạm Văn Tùng       5
# 2   7849857   68774130.0   8046945.0         Minh Giải       5
# 3  15666018  152449148.0   1333575.0         Genny Lee       5
# 4  17241576     655679.0  24504222.0         Nhật Việt       5
#
#                                     content  thank_count  rating_average  \
# 0                                       NaN            0             4.8
# 1                                       NaN            0             4.7
# 2                                       NaN            0             5.0
# 3  bộ truyện rất hay và giàu tính nhân văn.            0             4.9
# 4                                       NaN            0             4.9
#
#    count
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
train.shape
# Out:
# (140839, 9)

# %%
test.shape
# Out:
# (1423, 9)

# %%
book_information.shape
# Out:
# (16587, 17)

# %%
book_information.head(3)
# Out:
#                                             category  \
# 0  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
# 1  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
# 2  Nhà sách tiki/sách tiếng việt/sách bà mẹ em bé...
#
#                                                  url           id  \
# 0  https://tiki.vn/product-p141483251.html?spid=1...  141483251.0
# 1  https://tiki.vn/product-p125362334.html?spid=1...  125362334.0
# 2  https://tiki.vn/product-p58213080.html?spid=58...   58213080.0
#
#             sku                                               name     price  \
# 0  8.070578e+12  Sách: Thai Giáo Theo Chuyên Gia - 280 Ngày Mỗi...   80500.0
# 1  8.806987e+12  Dinh Dưỡng Thai Kỳ (Bà Bầu Ăn Gì Giúp Con Phát...  103950.0
# 2  4.467229e+12  Montessori – Phương Pháp Giáo Dục Toàn Diện Ch...   95200.0
#
#    rating_average  review_count  all_time_quantity_sold  \
# 0             5.0          58.0                   508.0
# 1             4.8          41.0                   486.0
# 2             5.0          16.0                   116.0
#
#                                          description  \
# 0  \nThai Giáo Theo Chuyên Gia, 280 Ngày, Mỗi Ngà...
# 1  “Dinh dưỡng thai kỳ” giống như một cuốn bách k...
# 2  MONTESSORI – PHƯƠNG PHÁP GIÁO DỤC TOÀN DIỆN CH...
#
#                                       specifications  seller_id    seller_sku  \
# 0  {"name": "Th\u00f4ng tin chung", "attributes":...    36846.0  3.544877e+12
# 1  {"name": "Th\u00f4ng tin chung", "attributes":...        1.0  6.946825e+12
# 2  {"name": "Th\u00f4ng tin chung", "attributes":...    53660.0  1.012848e+12
#
#        seller_name  seller_store_id  count_specification  \
# 0   Minh Long Book          36125.0                    5
# 1     Tiki Trading          40395.0                    7
# 2  Nhà sách Fahasa          51001.0                    6
#
#                                           attributes
# 0  {'id': 141483251.0, 'publisher_vn': 'Minh Long...
# 1  {'id': 125362334.0, 'publisher_vn': 'Booklife'...
# 2  {'id': 58213080.0, 'publisher_vn': '1980 Books...

# %% [markdown]
# # Một vài hàm lấy dữ liệu

# %%
def get_rating(userid, bookid):
    return (train.loc[((train.user_id== userid)&(train.product_id== bookid)), 'rating'].iloc[0])
#------------------------
def get_bookid(userid): 
    return (train.loc[(train.user_id==userid), 'product_id'].tolist())
#----------------------
def get_userid(bookid): 
    return (train.loc[(train.product_id==bookid), 'user_id'].tolist())
#------------------------
def get_food_title(bookid):
    return (book_information.loc[(book_information.id==bookid), 'name'].iloc[0])
#------------------------
def get_average_rating(userid):
    rating_user = train.loc[((train.user_id== userid)), 'rating']
    return np.mean(rating_user)
#-----------------------
def get_average_rating_book(bookid):
    rating_book = train.loc[((train.product_id== bookid)), 'rating']
    return np.mean(rating_book)

# %%
get_average_rating_book(58543601.0)
# Out:
# 4.826086956521739

# %%
average_rating_userid = {}
for i in train["user_id"].unique():
    average_rating_userid[i]=get_average_rating(i)

# %% [markdown]
# # Các hàm tính độ tương tự

# %% [markdown]
# ## Độ đo Cosine

# %%
def cosine_similarity_item(book1, book2):
    both_watch_count = 0
    for userid in train.loc[train.product_id == book1, 'user_id'].to_list():
        for userid in train.loc[train.product_id == book2, 'user_id'].tolist():
            both_watch_count +=1
    if both_watch_count == 0:
        return 0

    rating1 = []
    rating2 = []

    for userid in train.loc[train.product_id == book1, 'user_id'].to_list():
        if userid in train.loc[train.product_id == book2, 'user_id'].tolist():
            rating1.append(get_rating(userid, book1))
            rating2.append(get_rating(userid, book2))

    if (norm(rating1)*norm(rating2)) == 0:
        return 0
    return dot(rating1, rating2)/(norm(rating1)*norm(rating2))

# %%
cosine_similarity_item(10722462.0, 58543601.0)
# Out:
# 0

# %% [markdown]
# ## Độ đo tương tự Pearson

# %%
def pearson_correlation_item(book1, book2):
    both_watch_count = []
    for userid in train.loc[(train.product_id == book1), 'user_id'].tolist():
        if userid in train.loc[(train.product_id == book2), 'user_id'].tolist():
            both_watch_count.append(userid)
    if len(both_watch_count) == 0:
        return 0
    rating_sum_1 = sum([get_rating(userid, book1) for userid in both_watch_count])
    avg_rating_sum_1 = rating_sum_1/len(both_watch_count)

    rating_sum_2 = sum([get_rating(userid, book2) for userid in both_watch_count])
    avg_rating_sum_2 = rating_sum_2/len(both_watch_count)

    #Gia tri tren tu
    numerator = sum([(get_rating(userid, book1)- avg_rating_sum_1)*(get_rating(userid, book2) - avg_rating_sum_2) for userid in both_watch_count])
    denominator = sqrt(sum([pow((get_rating(userid, book1) - avg_rating_sum_1), 2) for userid in both_watch_count]))*sqrt(sum([pow((get_rating(userid, book2) - avg_rating_sum_2), 2) for userid in both_watch_count]))
    if denominator == 0:
        return 0
    return numerator/denominator

# %%
pearson_correlation_item(10722462.0, 58543601.0)
# Out:
# 0

# %% [markdown]
# # Hàm tính top k sách có độ tương đồng

# %%
def get_similarity_item(book1, number_of_book, metric_similar):
    book_ids = train.product_id.unique().tolist()

    similarity_score = []
    for foodID in book_ids[:500]:
        if (foodID != book1):
            if (metric_similar == "cosine"):
                similarity_score.append((cosine_similarity_item(book1, foodID), foodID))
            elif (metric_similar == "pearson"):
                similarity_score.append((pearson_correlation_item(book1, foodID), foodID))
    similarity_score.sort()
    similarity_score.reverse()
    return similarity_score[:number_of_book]

# %%
get_similarity_item( 58543601.0, 10, "pearson")
# Out:
# [(1.0000000000000002, 54120846.0),
#  (1.0000000000000002, 52789367.0),
#  (1.0, 37875476.0),
#  (1.0, 27582931.0),
#  (0.9999999999999998, 57180817.0),
#  (0.9999999999999998, 52329763.0),
#  (0.6123724356957948, 52788072.0),
#  (0.5000000000000001, 8885999.0),
#  (0.5000000000000001, 3071853.0),
#  (0.5, 70016692.0)]

# %% [markdown]
# # Hàm khuyến nghị sách

# %% [markdown]
# ## Khuyến nghị dựa trên trung bình đánh giá

# %%
def get_recommendation_tbdg_item(bookid, number_of_book, metric_similar):
    book_ids = train.product_id.unique().tolist()
    total = {}
    number_rating = {}
    List_similar = get_similarity_item(bookid, number_of_book, metric_similar)
    for peason, book in List_similar:
        for userid in get_userid(book):
            if userid not in get_userid(bookid) or get_rating(userid, bookid) == 0:
                if userid not in total:
                    total[userid] = 0
                    number_rating[userid] = 0
                    total[userid] += get_rating(userid, book)
                    if get_rating(userid, book) != 0:
                        number_rating[userid] +=1
                else:
                    total[userid] += get_rating(userid, book)
                    if get_rating(userid, book) != 0:
                        number_rating[userid] +=1
                
    ranking = [(to/number_rating[userid], userid) for userid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(userid, score) for score, userid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị dựa theo trung bình đánh giá có trọng số

# %%
def get_recommendation_tbdgcts_item(bookid, number_of_book, metric_similar):
    book_ids = train.product_id.unique().tolist()
    total = {}
    similarity_sum = {}
    List_similar = get_similarity_item(bookid, number_of_book, metric_similar)
    for peason, book in List_similar:
        score = peason
        for userid in get_userid(book):
            if userid not in get_userid(bookid) or get_rating(userid, bookid) == 0:
                if userid not in total:
                    total[userid] = 0
                    total[userid] += get_rating(userid, book)*score
                    similarity_sum [userid] = 0
                    similarity_sum [userid] +=score
                else:
                    total[userid] += get_rating(userid, book)*score
                    similarity_sum [userid] +=score
                
    ranking = [(to/similarity_sum[userid], userid) for userid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(userid, score) for score, userid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị dựa trên khoảng đánh giá

# %%
def get_recommendation_kdg_item(bookid, number_of_book, metric_similar):
    total = {}
    similarity_sum = {}
    List_similar = get_similarity_item(bookid, number_of_book, metric_similar)
    for peason, book in List_similar:
        score = peason
        for userid in get_userid(book):
            if userid not in get_userid(bookid) or get_rating(userid, bookid) == 0:
                if userid not in total:
                    total[userid] = 0
                    total[userid] += (get_rating(userid, book) - get_average_rating_book(book))*score
                    similarity_sum [userid] = 0
                    similarity_sum [userid] +=score
                else:
                    total[userid] += (get_rating(userid, book) - get_average_rating_book(book))*score
                    similarity_sum [userid] +=score
                
    ranking = [((get_average_rating_book(bookid) + to/similarity_sum[userid]), userid) for userid, to in total.items()]
    ranking.sort()
    ranking.reverse()

    recomendations = [(userid, score) for score, userid in ranking]

    return recomendations

# %% [markdown]
# ## Khuyến nghị sách

# %%
def get_recommendation_item(bookid, number_of_book, metrics_rating, metric_similar):
    if bookid not in list(train["product_id"].unique()):
        ranking = [(to, bookid) for bookid, to in average_rating_userid.items()]
        ranking.sort()
        ranking.reverse()
        recomendations = [(bookid, score) for score, bookid in ranking]
        return recomendations
    if (metrics_rating == "tbdg"):
        recomendations = get_recommendation_tbdg_item(bookid, number_of_book, metric_similar)
        return recomendations
    elif (metrics_rating == "tbdgcts"):
        recomendations = get_recommendation_tbdgcts_item(bookid, number_of_book, metric_similar)
        return recomendations
    elif (metrics_rating == "kdg"):
        recomendations = get_recommendation_kdg_item(bookid, number_of_book, metric_similar)
        return recomendations

# %%
# Thử nghiệm
book =  58543601.0
number_of_book = 10
metrics_rating = "kdg" # 1 trong 3 ["tbdg", "tbdgctg", "kdg"]
metrics_similar = "cosine" # 1 trong 2 ["cosine", "peason"]
book_recommend = get_recommendation_item(book, number_of_book, metrics_rating, metrics_similar)

# %%
book_recommend
# Out:
# [(26044245.0, 5.120204603580563),
#  (21474832.0, 5.120204603580563),
#  (21151479.0, 5.120204603580563),
#  (12205402.0, 5.120204603580563),
#  (11790919.0, 5.120204603580563),
#  (8094853.0, 5.120204603580563),
#  (7178520.0, 5.120204603580563),
#  (7107873.0, 5.120204603580563),
#  (6087484.0, 5.120204603580563),
#  (5770824.0, 5.120204603580563),
#  (5359550.0, 5.120204603580563),
#  (1997514.0, 5.120204603580563),
#  (708667.0, 5.120204603580563),
#  (16754605.0, 4.992753623188406),
#  (10011149.0, 4.992753623188406),
#  (6158890.0, 4.992753623188406),
#  (456030.0, 4.992753623188406),
#  (632189.0, 4.985966292871664),
#  (11634258.0, 4.9689440993788825),
#  (11525835.0, 4.9689440993788825),
#  (5805473.0, 4.9689440993788825),
#  (522878.0, 4.9689440993788825),
#  (385406.0, 4.9689440993788825),
#  (311452.0, 4.9689440993788825),
#  (33282.0, 4.9689440993788825),
#  (25960212.0, 4.9480381760339345),
#  (25058444.0, 4.9480381760339345),
#  (21600295.0, 4.9480381760339345),
#  (21251784.0, 4.9480381760339345),
#  (20299308.0, 4.9480381760339345),
#  (20075171.0, 4.9480381760339345),
#  (19628093.0, 4.9480381760339345),
#  (18999680.0, 4.9480381760339345),
#  (15852368.0, 4.9480381760339345),
#  (15191319.0, 4.9480381760339345),
#  (11752211.0, 4.9480381760339345),
#  (10858491.0, 4.9480381760339345),
#  (8146388.0, 4.9480381760339345),
#  (7931593.0, 4.9480381760339345),
#  (7774479.0, 4.9480381760339345),
#  (7249302.0, 4.9480381760339345),
#  (5973708.0, 4.9480381760339345),
#  (1873402.0, 4.9480381760339345),
#  (1484163.0, 4.9480381760339345),
#  (545201.0, 4.9480381760339345),
#  (357419.0, 4.9480381760339345),
#  (116696.0, 4.9480381760339345),
#  (90147.0, 4.9480381760339345),
#  (40835.0, 4.9480381760339345),
#  (6729273.0, 4.917990401329384),
#  (456993.0, 4.917990401329384),
#  (42211.0, 4.917990401329384),
#  (16423452.0, 4.912667043101826),
#  (12119040.0, 4.904425570942828),
#  (432136.0, 4.903333569850827),
#  (18522536.0, 4.902214081429352),
#  (26928494.0, 4.9005760797913505),
#  (13620930.0, 4.9005760797913505),
#  (8676951.0, 4.9005760797913505),
#  (7831209.0, 4.9005760797913505),
#  (6471588.0, 4.9005760797913505),
#  (1938491.0, 4.9005760797913505),
#  (470130.0, 4.9005760797913505),
#  (48839.0, 4.9005760797913505),
#  (27683454.0, 4.887942626624832),
#  (26054766.0, 4.887942626624832),
#  (22660552.0, 4.887942626624832),
#  (22365637.0, 4.887942626624832),
#  (22094564.0, 4.887942626624832),
#  (20440557.0, 4.887942626624832),
#  (20048996.0, 4.887942626624832),
#  (19763709.0, 4.887942626624832),
#  (19241351.0, 4.887942626624832),
#  (18611195.0, 4.887942626624832),
#  (16308846.0, 4.887942626624832),
#  (16073977.0, 4.887942626624832),
#  (15828255.0, 4.887942626624832),
#  (15253934.0, 4.887942626624832),
#  (15076836.0, 4.887942626624832),
#  (15052614.0, 4.887942626624832),
#  (14387711.0, 4.887942626624832),
#  (13613283.0, 4.887942626624832),
#  (13098857.0, 4.887942626624832),
#  (12637928.0, 4.887942626624832),
#  (12388948.0, 4.887942626624832),
#  (11966988.0, 4.887942626624832),
#  (11512407.0, 4.887942626624832),
#  (10903486.0, 4.887942626624832),
#  (8926117.0, 4.887942626624832),
#  (8901353.0, 4.887942626624832),
#  (8766526.0, 4.887942626624832),
#  (8671821.0, 4.887942626624832),
#  (8542922.0, 4.887942626624832),
#  (7915518.0, 4.887942626624832),
#  (6602742.0, 4.887942626624832),
#  (6236828.0, 4.887942626624832),
#  (6139254.0, 4.887942626624832),
#  (5886329.0, 4.887942626624832),
#  (5652979.0, 4.887942626624832),
#  (5582356.0, 4.887942626624832),
#  (5305474.0, 4.887942626624832),
#  (5195993.0, 4.887942626624832),
#  (1905237.0, 4.887942626624832),
#  (1840367.0, 4.887942626624832),
#  (1826533.0, 4.887942626624832),
#  (1718011.0, 4.887942626624832),
#  (1635513.0, 4.887942626624832),
#  (1602684.0, 4.887942626624832),
#  (1302791.0, 4.887942626624832),
#  (1241579.0, 4.887942626624832),
#  (1241170.0, 4.887942626624832),
#  (884762.0, 4.887942626624832),
#  (651924.0, 4.887942626624832),
#  (592244.0, 4.887942626624832),
#  (560826.0, 4.887942626624832),
#  (362320.0, 4.887942626624832),
#  (326728.0, 4.887942626624832),
#  (186696.0, 4.887942626624832),
#  (149531.0, 4.887942626624832),
#  (105673.0, 4.887942626624832),
#  (84640.0, 4.887942626624832),
#  (66924.0, 4.887942626624832),
#  (65143.0, 4.887942626624832),
#  (11878.0, 4.887942626624832),
#  (18782481.0, 4.881405035475725),
#  (12138328.0, 4.881405035475725),
#  (10798637.0, 4.881405035475725),
#  (1654.0, 4.881405035475725),
#  (9786862.0, 4.877425080024811),
#  (16732541.0, 4.877014791573286),
#  (7872456.0, 4.877014791573286),
#  (28236424.0, 4.874867444326617),
#  (22742379.0, 4.874867444326617),
#  (22414466.0, 4.874867444326617),
#  (21390673.0, 4.874867444326617),
#  (18577503.0, 4.874867444326617),
#  (18117602.0, 4.874867444326617),
#  (17577448.0, 4.874867444326617),
#  (17535659.0, 4.874867444326617),
#  (17153193.0, 4.874867444326617),
#  (15432738.0, 4.874867444326617),
#  (12838006.0, 4.874867444326617),
#  (11672746.0, 4.874867444326617),
#  (9890777.0, 4.874867444326617),
#  (9641067.0, 4.874867444326617),
#  (8471563.0, 4.874867444326617),
#  (8263278.0, 4.874867444326617),
#  (8012920.0, 4.874867444326617),
#  (6092900.0, 4.874867444326617),
#  (5897437.0, 4.874867444326617),
#  (5383234.0, 4.874867444326617),
#  (1700584.0, 4.874867444326617),
#  (1386875.0, 4.874867444326617),
#  (1105511.0, 4.874867444326617),
#  (874713.0, 4.874867444326617),
#  (727348.0, 4.874867444326617),
#  (599551.0, 4.874867444326617),
#  (445395.0, 4.874867444326617),
#  (412831.0, 4.874867444326617),
#  (318283.0, 4.874867444326617),
#  (177919.0, 4.874867444326617),
#  (155753.0, 4.874867444326617),
#  (13552.0, 4.874867444326617),
#  (17088516.0, 4.8721663067248),
#  (16728544.0, 4.8721663067248),
#  (13505112.0, 4.8721663067248),
#  (7378071.0, 4.8721663067248),
#  (5897740.0, 4.8721663067248),
#  (5287412.0, 4.8721663067248),
#  (803921.0, 4.8721663067248),
#  (22284547.0, 4.870528305086799),
#  (20297611.0, 4.870528305086799),
#  (1192677.0, 4.870528305086799),
#  (23982713.0, 4.869835304393798),
#  (24696507.0, 4.866086956521739),
#  (22527707.0, 4.866086956521739),
#  (20201126.0, 4.866086956521739),
#  (13053987.0, 4.866086956521739),
#  (12730643.0, 4.866086956521739),
#  (12705959.0, 4.866086956521739),
#  (11114680.0, 4.866086956521739),
#  (10421897.0, 4.866086956521739),
#  (10088955.0, 4.866086956521739),
#  (9921062.0, 4.866086956521739),
#  (8966245.0, 4.866086956521739),
#  (8695618.0, 4.866086956521739),
#  (8293230.0, 4.866086956521739),
#  (7707283.0, 4.866086956521739),
#  (5979039.0, 4.866086956521739),
#  (5363251.0, 4.866086956521739),
#  (5255318.0, 4.866086956521739),
#  (2052582.0, 4.866086956521739),
#  (1128327.0, 4.866086956521739),
#  (641311.0, 4.866086956521739),
#  (168220.0, 4.866086956521739),
#  (24304082.0, 4.865815532332789),
#  (10078216.0, 4.865815532332789),
#  (51302.0, 4.865815532332789),
#  (27656632.0, 4.8563899868247695),
#  (27018419.0, 4.8563899868247695),
#  (21554002.0, 4.8563899868247695),
#  (20375252.0, 4.8563899868247695),
#  (16043266.0, 4.8563899868247695),
#  (15990063.0, 4.8563899868247695),
#  (13430694.0, 4.8563899868247695),
#  (13085968.0, 4.8563899868247695),
#  (8200000.0, 4.8563899868247695),
#  (2176074.0, 4.8563899868247695),
#  (1483681.0, 4.8563899868247695),
#  (810311.0, 4.8563899868247695),
#  (26269.0, 4.8563899868247695),
#  (2426.0, 4.8563899868247695),
#  (7197425.0, 4.854751985186768),
#  (620317.0, 4.854751985186768),
#  (22758456.0, 4.853113983548766),
#  (22749021.0, 4.853113983548766),
#  (21182697.0, 4.853113983548766),
#  (19932254.0, 4.853113983548766),
#  (19714546.0, 4.853113983548766),
#  (19158309.0, 4.853113983548766),
#  (19009402.0, 4.853113983548766),
#  (16947763.0, 4.853113983548766),
#  (15701232.0, 4.853113983548766),
#  (14343738.0, 4.853113983548766),
#  (12709622.0, 4.853113983548766),
#  (11787530.0, 4.853113983548766),
#  (11667082.0, 4.853113983548766),
#  (11483560.0, 4.853113983548766),
#  (11294668.0, 4.853113983548766),
#  (9789241.0, 4.853113983548766),
#  (9745026.0, 4.853113983548766),
#  (9122070.0, 4.853113983548766),
#  (7489632.0, 4.853113983548766),
#  (6429426.0, 4.853113983548766),
#  (6416638.0, 4.853113983548766),
#  (5951960.0, 4.853113983548766),
#  (5725311.0, 4.853113983548766),
#  (5590560.0, 4.853113983548766),
#  (5274223.0, 4.853113983548766),
#  (5253296.0, 4.853113983548766),
#  (5091787.0, 4.853113983548766),
#  (2212061.0, 4.853113983548766),
#  (2132102.0, 4.853113983548766),
#  (2030863.0, 4.853113983548766),
#  (1994386.0, 4.853113983548766),
#  (1425077.0, 4.853113983548766),
#  (1399144.0, 4.853113983548766),
#  (1284127.0, 4.853113983548766),
#  (1142234.0, 4.853113983548766),
#  (878192.0, 4.853113983548766),
#  (875376.0, 4.853113983548766),
#  (839630.0, 4.853113983548766),
#  (823422.0, 4.853113983548766),
#  (678849.0, 4.853113983548766),
#  (591546.0, 4.853113983548766),
#  (230068.0, 4.853113983548766),
#  (137098.0, 4.853113983548766),
#  (136475.0, 4.853113983548766),
#  (112334.0, 4.853113983548766),
#  (104748.0, 4.853113983548766),
#  (96595.0, 4.853113983548766),
#  (83173.0, 4.853113983548766),
#  (81526.0, 4.853113983548766),
#  (12751.0, 4.853113983548766),
#  (27.0, 4.853113983548766),
#  (26599764.0, 4.851727982162765),
#  (24283374.0, 4.851727982162765),
#  (21692875.0, 4.851727982162765),
#  (21544324.0, 4.851727982162765),
#  (19498985.0, 4.851727982162765),
#  (17798539.0, 4.851727982162765),
#  (16674776.0, 4.851727982162765),
#  (13932185.0, 4.851727982162765),
#  (13513176.0, 4.851727982162765),
#  (13115098.0, 4.851727982162765),
#  (11280300.0, 4.851727982162765),
#  (11130645.0, 4.851727982162765),
#  (10938863.0, 4.851727982162765),
#  (10025671.0, 4.851727982162765),
#  (8579524.0, 4.851727982162765),
#  (8471425.0, 4.851727982162765),
#  (8228686.0, 4.851727982162765),
#  (7721465.0, 4.851727982162765),
#  (7621628.0, 4.851727982162765),
#  (7336791.0, 4.851727982162765),
#  (7333002.0, 4.851727982162765),
#  (6711797.0, 4.851727982162765),
#  (6278292.0, 4.851727982162765),
#  (5953228.0, 4.851727982162765),
#  (5277307.0, 4.851727982162765),
#  (2227428.0, 4.851727982162765),
#  (2073251.0, 4.851727982162765),
#  (1939069.0, 4.851727982162765),
#  (1213614.0, 4.851727982162765),
#  (990696.0, 4.851727982162765),
#  (554987.0, 4.851727982162765),
#  (281890.0, 4.851727982162765),
#  (83040.0, 4.851727982162765),
#  (81619.0, 4.851727982162765),
#  (42438.0, 4.851727982162765),
#  (68275.0, 4.699338337090193),
#  (7859171.0, 4.572335293982046),
#  (24383594.0, 4.381405035475725),
#  (478556.0, 4.381405035475725),
#  (5339281.0, 4.120204603580563),
#  (1333575.0, 3.9689440993788825),
#  (6047040.0, 3.9480381760339345),
#  (21424135.0, 3.887942626624832),
#  (17552126.0, 3.887942626624832),
#  (12743202.0, 3.887942626624832),
#  (8992758.0, 3.887942626624832),
#  (891764.0, 3.887942626624832),
#  (1282193.0, 3.8721663067248007),
#  (18278431.0, 3.8660869565217393),
#  (20069380.0, 3.8531139835487664),
#  (373997.0, 3.8531139835487664),
#  (12966926.0, 1.1202046035805626),
#  (8145881.0, 0.9480381760339345)]

# %% [markdown]
# # Đánh giá phương pháp

# %%
def get_recommendation_4test_item(X_test, number_of_book, metrics_rating, metric_similar):
    X_test_pred = []
    X_test_userid = X_test['user_id'].tolist()
    X_test_bookId = X_test['product_id'].tolist()
    print("Dự đoán cho tập test với {} điểm dữ liệu".format(len(X_test_bookId)))
    for i in range(len(X_test_bookId)):
        list_R = get_recommendation_item(X_test_bookId[i], number_of_book, metrics_rating, metrics_similar)
        check = 0
        for j in list_R:
            if(X_test_userid[i] == j[0]):
                X_test_pred.append(j[1])
                check = 1
        if(check == 0 ):
            X_test_pred.append(0)
        print('----------dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i]))
    return X_test_pred

# %% [markdown]
# ## Dự đoán và đánh giá bằng pp TBDG và peason

# %%
import time
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
import time
start = time.time()
number_similar = 100
metrics_rating = "tbdg" # 1 trong 3 ["tbdg", "tbdgctg", "kdg"]
metrics_similar = "pearson" # 1 trong 2 ["cosine", "pearson"]
X_test_pred_rating = get_recommendation_4test_item(test, number_similar, metrics_rating, metrics_similar)

end = time.time()

print("Tổng thời gian dự đoán :", end - start)
# Out:
# Dự đoán cho tập test với 1423 điểm dữ liệu
# ----------dự đoán cho dòng thứ 0 là 0
# ----------dự đoán cho dòng thứ 1 là 3.6666666666666665
# ----------dự đoán cho dòng thứ 2 là 5.0
# ----------dự đoán cho dòng thứ 3 là 5.0
# ----------dự đoán cho dòng thứ 4 là 0
# ----------dự đoán cho dòng thứ 5 là 4.684684684684685
# ----------dự đoán cho dòng thứ 6 là 5.0
# ----------dự đoán cho dòng thứ 7 là 0
# ----------dự đoán cho dòng thứ 8 là 5.0
# ----------dự đoán cho dòng thứ 9 là 0
# ----------dự đoán cho dòng thứ 10 là 0
# ----------dự đoán cho dòng thứ 11 là 0
# ----------dự đoán cho dòng thứ 12 là 4.666666666666667
# ----------dự đoán cho dòng thứ 13 là 5.0
# ----------dự đoán cho dòng thứ 14 là 0
# ----------dự đoán cho dòng thứ 15 là 4.75
# ----------dự đoán cho dòng thứ 16 là 0
# ----------dự đoán cho dòng thứ 17 là 5.0
# ----------dự đoán cho dòng thứ 18 là 0
# ----------dự đoán cho dòng thứ 19 là 5.0
# ----------dự đoán cho dòng thứ 20 là 0
# ----------dự đoán cho dòng thứ 21 là 5.0
# ----------dự đoán cho dòng thứ 22 là 0
# ----------dự đoán cho dòng thứ 23 là 0
# ----------dự đoán cho dòng thứ 24 là 5.0
# ----------dự đoán cho dòng thứ 25 là 0
# ----------dự đoán cho dòng thứ 26 là 5.0
# ----------dự đoán cho dòng thứ 27 là 0
# ----------dự đoán cho dòng thứ 28 là 0
# ----------dự đoán cho dòng thứ 29 là 5.0
# ----------dự đoán cho dòng thứ 30 là 5.0
# ----------dự đoán cho dòng thứ 31 là 0
# ----------dự đoán cho dòng thứ 32 là 5.0
# ----------dự đoán cho dòng thứ 33 là 4.666666666666667
# ----------dự đoán cho dòng thứ 34 là 4.333333333333333
# ----------dự đoán cho dòng thứ 35 là 5.0
# ----------dự đoán cho dòng thứ 36 là 0
# ----------dự đoán cho dòng thứ 37 là 0
# ----------dự đoán cho dòng thứ 38 là 0
# ----------dự đoán cho dòng thứ 39 là 4.0
# ----------dự đoán cho dòng thứ 40 là 0
# ----------dự đoán cho dòng thứ 41 là 5.0
# ----------dự đoán cho dòng thứ 42 là 5.0
# ----------dự đoán cho dòng thứ 43 là 0
# ----------dự đoán cho dòng thứ 44 là 4.625
# ----------dự đoán cho dòng thứ 45 là 0
# ----------dự đoán cho dòng thứ 46 là 5.0
# ----------dự đoán cho dòng thứ 47 là 5.0
# ----------dự đoán cho dòng thứ 48 là 4.714285714285714
# ----------dự đoán cho dòng thứ 49 là 0
# ----------dự đoán cho dòng thứ 50 là 0
# ----------dự đoán cho dòng thứ 51 là 5.0
# ----------dự đoán cho dòng thứ 52 là 0
# ----------dự đoán cho dòng thứ 53 là 0
# ----------dự đoán cho dòng thứ 54 là 0
# ----------dự đoán cho dòng thứ 55 là 0
# ----------dự đoán cho dòng thứ 56 là 0
# ----------dự đoán cho dòng thứ 57 là 4.333333333333333
# ----------dự đoán cho dòng thứ 58 là 5.0
# ----------dự đoán cho dòng thứ 59 là 0
# ----------dự đoán cho dòng thứ 60 là 3.0
# ----------dự đoán cho dòng thứ 61 là 5.0
# ----------dự đoán cho dòng thứ 62 là 0
# ----------dự đoán cho dòng thứ 63 là 0
# ----------dự đoán cho dòng thứ 64 là 5.0
# ----------dự đoán cho dòng thứ 65 là 0
# ----------dự đoán cho dòng thứ 66 là 0
# ----------dự đoán cho dòng thứ 67 là 0
# ----------dự đoán cho dòng thứ 68 là 4.956521739130435
# ----------dự đoán cho dòng thứ 69 là 5.0
# ----------dự đoán cho dòng thứ 70 là 0
# ----------dự đoán cho dòng thứ 71 là 5.0
# ----------dự đoán cho dòng thứ 72 là 0
# ----------dự đoán cho dòng thứ 73 là 5.0
# ----------dự đoán cho dòng thứ 74 là 5.0
# ----------dự đoán cho dòng thứ 75 là 0
# ----------dự đoán cho dòng thứ 76 là 5.0
# ----------dự đoán cho dòng thứ 77 là 0
# ----------dự đoán cho dòng thứ 78 là 5.0
# ----------dự đoán cho dòng thứ 79 là 5.0
# ----------dự đoán cho dòng thứ 80 là 5.0
# ----------dự đoán cho dòng thứ 81 là 5.0
# ----------dự đoán cho dòng thứ 82 là 0
# ----------dự đoán cho dòng thứ 83 là 4.0
# ----------dự đoán cho dòng thứ 84 là 0
# ----------dự đoán cho dòng thứ 85 là 5.0
# ----------dự đoán cho dòng thứ 86 là 0
# ----------dự đoán cho dòng thứ 87 là 0
# ----------dự đoán cho dòng thứ 88 là 5.0
# ----------dự đoán cho dòng thứ 89 là 5.0
# ----------dự đoán cho dòng thứ 90 là 5.0
# ----------dự đoán cho dòng thứ 91 là 5.0
# ----------dự đoán cho dòng thứ 92 là 5.0
# ----------dự đoán cho dòng thứ 93 là 0
# ----------dự đoán cho dòng thứ 94 là 4.0
# ----------dự đoán cho dòng thứ 95 là 0
# ----------dự đoán cho dòng thứ 96 là 0
# ----------dự đoán cho dòng thứ 97 là 0
# ----------dự đoán cho dòng thứ 98 là 0
# ----------dự đoán cho dòng thứ 99 là 4.753623188405797
# ----------dự đoán cho dòng thứ 100 là 5.0
# ----------dự đoán cho dòng thứ 101 là 0
# ----------dự đoán cho dòng thứ 102 là 0
# ----------dự đoán cho dòng thứ 103 là 0
# ----------dự đoán cho dòng thứ 104 là 0
# ----------dự đoán cho dòng thứ 105 là 5.0
# ----------dự đoán cho dòng thứ 106 là 5.0
# ----------dự đoán cho dòng thứ 107 là 5.0
# ----------dự đoán cho dòng thứ 108 là 4.0
# ----------dự đoán cho dòng thứ 109 là 0
# ----------dự đoán cho dòng thứ 110 là 0
# ----------dự đoán cho dòng thứ 111 là 4.777777777777778
# ----------dự đoán cho dòng thứ 112 là 5.0
# ----------dự đoán cho dòng thứ 113 là 5.0
# ----------dự đoán cho dòng thứ 114 là 0
# ----------dự đoán cho dòng thứ 115 là 0
# ----------dự đoán cho dòng thứ 116 là 5.0
# ----------dự đoán cho dòng thứ 117 là 0
# ----------dự đoán cho dòng thứ 118 là 5.0
# ----------dự đoán cho dòng thứ 119 là 0
# ----------dự đoán cho dòng thứ 120 là 0
# ----------dự đoán cho dòng thứ 121 là 5.0
# ----------dự đoán cho dòng thứ 122 là 0
# ----------dự đoán cho dòng thứ 123 là 0
# ----------dự đoán cho dòng thứ 124 là 0
# ----------dự đoán cho dòng thứ 125 là 0
# ----------dự đoán cho dòng thứ 126 là 0
# ----------dự đoán cho dòng thứ 127 là 0
# ----------dự đoán cho dòng thứ 128 là 0
# ----------dự đoán cho dòng thứ 129 là 0
# ----------dự đoán cho dòng thứ 130 là 5.0
# ----------dự đoán cho dòng thứ 131 là 0
# ----------dự đoán cho dòng thứ 132 là 5.0
# ----------dự đoán cho dòng thứ 133 là 0
# ----------dự đoán cho dòng thứ 134 là 5.0
# ----------dự đoán cho dòng thứ 135 là 4.867924528301887
# ----------dự đoán cho dòng thứ 136 là 0
# ----------dự đoán cho dòng thứ 137 là 0
# ----------dự đoán cho dòng thứ 138 là 0
# ----------dự đoán cho dòng thứ 139 là 0
# ----------dự đoán cho dòng thứ 140 là 0
# ----------dự đoán cho dòng thứ 141 là 0
# ----------dự đoán cho dòng thứ 142 là 5.0
# ----------dự đoán cho dòng thứ 143 là 0
# ----------dự đoán cho dòng thứ 144 là 4.0
# ----------dự đoán cho dòng thứ 145 là 0
# ----------dự đoán cho dòng thứ 146 là 0
# ----------dự đoán cho dòng thứ 147 là 0
# ----------dự đoán cho dòng thứ 148 là 0
# ----------dự đoán cho dòng thứ 149 là 0
# ----------dự đoán cho dòng thứ 150 là 5.0
# ----------dự đoán cho dòng thứ 151 là 5.0
# ----------dự đoán cho dòng thứ 152 là 5.0
# ----------dự đoán cho dòng thứ 153 là 4.295774647887324
# ----------dự đoán cho dòng thứ 154 là 5.0
# ----------dự đoán cho dòng thứ 155 là 0
# ----------dự đoán cho dòng thứ 156 là 4.0
# ----------dự đoán cho dòng thứ 157 là 5.0
# ----------dự đoán cho dòng thứ 158 là 3.6
# ----------dự đoán cho dòng thứ 159 là 5.0
# ----------dự đoán cho dòng thứ 160 là 5.0
# ----------dự đoán cho dòng thứ 161 là 5.0
# ----------dự đoán cho dòng thứ 162 là 5.0
# ----------dự đoán cho dòng thứ 163 là 0
# ----------dự đoán cho dòng thứ 164 là 5.0
# ----------dự đoán cho dòng thứ 165 là 0
# ----------dự đoán cho dòng thứ 166 là 5.0
# ----------dự đoán cho dòng thứ 167 là 5.0
# ----------dự đoán cho dòng thứ 168 là 5.0
# ----------dự đoán cho dòng thứ 169 là 5.0
# ----------dự đoán cho dòng thứ 170 là 0
# ----------dự đoán cho dòng thứ 171 là 0
# ----------dự đoán cho dòng thứ 172 là 5.0
# ----------dự đoán cho dòng thứ 173 là 5.0
# ----------dự đoán cho dòng thứ 174 là 5.0
# ----------dự đoán cho dòng thứ 175 là 5.0
# ----------dự đoán cho dòng thứ 176 là 4.636363636363637
# ----------dự đoán cho dòng thứ 177 là 5.0
# ----------dự đoán cho dòng thứ 178 là 5.0
# ----------dự đoán cho dòng thứ 179 là 5.0
# ----------dự đoán cho dòng thứ 180 là 0
# ----------dự đoán cho dòng thứ 181 là 0
# ----------dự đoán cho dòng thứ 182 là 5.0
# ----------dự đoán cho dòng thứ 183 là 5.0
# ----------dự đoán cho dòng thứ 184 là 5.0
# ----------dự đoán cho dòng thứ 185 là 5.0
# ----------dự đoán cho dòng thứ 186 là 5.0
# ----------dự đoán cho dòng thứ 187 là 5.0
# ----------dự đoán cho dòng thứ 188 là 5.0
# ----------dự đoán cho dòng thứ 189 là 0
# ----------dự đoán cho dòng thứ 190 là 0
# ----------dự đoán cho dòng thứ 191 là 5.0
# ----------dự đoán cho dòng thứ 192 là 0
# ----------dự đoán cho dòng thứ 193 là 0
# ----------dự đoán cho dòng thứ 194 là 5.0
# ----------dự đoán cho dòng thứ 195 là 0
# ----------dự đoán cho dòng thứ 196 là 4.0
# ----------dự đoán cho dòng thứ 197 là 4.5
# ----------dự đoán cho dòng thứ 198 là 5.0
# ----------dự đoán cho dòng thứ 199 là 0
# ----------dự đoán cho dòng thứ 200 là 5.0
# ----------dự đoán cho dòng thứ 201 là 0
# ----------dự đoán cho dòng thứ 202 là 5.0
# ----------dự đoán cho dòng thứ 203 là 5.0
# ----------dự đoán cho dòng thứ 204 là 5.0
# ----------dự đoán cho dòng thứ 205 là 5.0
# ----------dự đoán cho dòng thứ 206 là 0
# ----------dự đoán cho dòng thứ 207 là 4.0
# ----------dự đoán cho dòng thứ 208 là 0
# ----------dự đoán cho dòng thứ 209 là 5.0
# ----------dự đoán cho dòng thứ 210 là 4.0
# ----------dự đoán cho dòng thứ 211 là 0
# ----------dự đoán cho dòng thứ 212 là 0
# ----------dự đoán cho dòng thứ 213 là 5.0
# ----------dự đoán cho dòng thứ 214 là 5.0
# ----------dự đoán cho dòng thứ 215 là 0
# ----------dự đoán cho dòng thứ 216 là 5.0
# ----------dự đoán cho dòng thứ 217 là 0
# ----------dự đoán cho dòng thứ 218 là 0
# ----------dự đoán cho dòng thứ 219 là 5.0
# ----------dự đoán cho dòng thứ 220 là 0
# ----------dự đoán cho dòng thứ 221 là 0
# ----------dự đoán cho dòng thứ 222 là 5.0
# ----------dự đoán cho dòng thứ 223 là 2.8333333333333335
# ----------dự đoán cho dòng thứ 224 là 0
# ----------dự đoán cho dòng thứ 225 là 5.0
# ----------dự đoán cho dòng thứ 226 là 0
# ----------dự đoán cho dòng thứ 227 là 5.0
# ----------dự đoán cho dòng thứ 228 là 4.0588235294117645
# ----------dự đoán cho dòng thứ 229 là 0
# ----------dự đoán cho dòng thứ 230 là 5.0
# ----------dự đoán cho dòng thứ 231 là 0
# ----------dự đoán cho dòng thứ 232 là 4.208333333333333
# ----------dự đoán cho dòng thứ 233 là 0
# ----------dự đoán cho dòng thứ 234 là 0
# ----------dự đoán cho dòng thứ 235 là 4.203703703703703
# ----------dự đoán cho dòng thứ 236 là 0
# ----------dự đoán cho dòng thứ 237 là 5.0
# ----------dự đoán cho dòng thứ 238 là 0
# ----------dự đoán cho dòng thứ 239 là 5.0
# ----------dự đoán cho dòng thứ 240 là 5.0
# ----------dự đoán cho dòng thứ 241 là 5.0
# ----------dự đoán cho dòng thứ 242 là 5.0
# ----------dự đoán cho dòng thứ 243 là 5.0
# ----------dự đoán cho dòng thứ 244 là 5.0
# ----------dự đoán cho dòng thứ 245 là 0
# ----------dự đoán cho dòng thứ 246 là 4.0
# ----------dự đoán cho dòng thứ 247 là 5.0
# ----------dự đoán cho dòng thứ 248 là 4.0
# ----------dự đoán cho dòng thứ 249 là 4.961038961038961
# ----------dự đoán cho dòng thứ 250 là 0
# ----------dự đoán cho dòng thứ 251 là 5.0
# ----------dự đoán cho dòng thứ 252 là 0
# ----------dự đoán cho dòng thứ 253 là 5.0
# ----------dự đoán cho dòng thứ 254 là 0
# ----------dự đoán cho dòng thứ 255 là 0
# ----------dự đoán cho dòng thứ 256 là 5.0
# ----------dự đoán cho dòng thứ 257 là 4.8
# ----------dự đoán cho dòng thứ 258 là 4.874074074074074
# ----------dự đoán cho dòng thứ 259 là 0
# ----------dự đoán cho dòng thứ 260 là 5.0
# ----------dự đoán cho dòng thứ 261 là 5.0
# ----------dự đoán cho dòng thứ 262 là 0
# ----------dự đoán cho dòng thứ 263 là 5.0
# ----------dự đoán cho dòng thứ 264 là 5.0
# ----------dự đoán cho dòng thứ 265 là 0
# ----------dự đoán cho dòng thứ 266 là 0
# ----------dự đoán cho dòng thứ 267 là 5.0
# ----------dự đoán cho dòng thứ 268 là 0
# ----------dự đoán cho dòng thứ 269 là 5.0
# ----------dự đoán cho dòng thứ 270 là 5.0
# ----------dự đoán cho dòng thứ 271 là 0
# ----------dự đoán cho dòng thứ 272 là 5.0
# ----------dự đoán cho dòng thứ 273 là 4.857142857142857
# ----------dự đoán cho dòng thứ 274 là 0
# ----------dự đoán cho dòng thứ 275 là 5.0
# ----------dự đoán cho dòng thứ 276 là 0
# ----------dự đoán cho dòng thứ 277 là 5.0
# ----------dự đoán cho dòng thứ 278 là 5.0
# ----------dự đoán cho dòng thứ 279 là 0
# ----------dự đoán cho dòng thứ 280 là 0
# ----------dự đoán cho dòng thứ 281 là 0
# ----------dự đoán cho dòng thứ 282 là 5.0
# ----------dự đoán cho dòng thứ 283 là 5.0
# ----------dự đoán cho dòng thứ 284 là 5.0
# ----------dự đoán cho dòng thứ 285 là 0
# ----------dự đoán cho dòng thứ 286 là 5.0
# ----------dự đoán cho dòng thứ 287 là 0
# ----------dự đoán cho dòng thứ 288 là 5.0
# ----------dự đoán cho dòng thứ 289 là 0
# ----------dự đoán cho dòng thứ 290 là 5.0
# ----------dự đoán cho dòng thứ 291 là 5.0
# ----------dự đoán cho dòng thứ 292 là 0
# ----------dự đoán cho dòng thứ 293 là 5.0
# ----------dự đoán cho dòng thứ 294 là 4.9
# ----------dự đoán cho dòng thứ 295 là 0
# ----------dự đoán cho dòng thứ 296 là 5.0
# ----------dự đoán cho dòng thứ 297 là 0
# ----------dự đoán cho dòng thứ 298 là 0
# ----------dự đoán cho dòng thứ 299 là 5.0
# ----------dự đoán cho dòng thứ 300 là 5.0
# ----------dự đoán cho dòng thứ 301 là 0
# ----------dự đoán cho dòng thứ 302 là 5.0
# ----------dự đoán cho dòng thứ 303 là 4.333333333333333
# ----------dự đoán cho dòng thứ 304 là 5.0
# ----------dự đoán cho dòng thứ 305 là 5.0
# ----------dự đoán cho dòng thứ 306 là 0
# ----------dự đoán cho dòng thứ 307 là 0
# ----------dự đoán cho dòng thứ 308 là 0
# ----------dự đoán cho dòng thứ 309 là 0
# ----------dự đoán cho dòng thứ 310 là 5.0
# ----------dự đoán cho dòng thứ 311 là 5.0
# ----------dự đoán cho dòng thứ 312 là 0
# ----------dự đoán cho dòng thứ 313 là 0
# ----------dự đoán cho dòng thứ 314 là 5.0
# ----------dự đoán cho dòng thứ 315 là 0
# ----------dự đoán cho dòng thứ 316 là 5.0
# ----------dự đoán cho dòng thứ 317 là 4.551724137931035
# ----------dự đoán cho dòng thứ 318 là 0
# ----------dự đoán cho dòng thứ 319 là 5.0
# ----------dự đoán cho dòng thứ 320 là 5.0
# ----------dự đoán cho dòng thứ 321 là 5.0
# ----------dự đoán cho dòng thứ 322 là 5.0
# ----------dự đoán cho dòng thứ 323 là 5.0
# ----------dự đoán cho dòng thứ 324 là 0
# ----------dự đoán cho dòng thứ 325 là 0
# ----------dự đoán cho dòng thứ 326 là 5.0
# ----------dự đoán cho dòng thứ 327 là 5.0
# ----------dự đoán cho dòng thứ 328 là 0
# ----------dự đoán cho dòng thứ 329 là 0
# ----------dự đoán cho dòng thứ 330 là 0
# ----------dự đoán cho dòng thứ 331 là 5.0
# ----------dự đoán cho dòng thứ 332 là 5.0
# ----------dự đoán cho dòng thứ 333 là 0
# ----------dự đoán cho dòng thứ 334 là 5.0
# ----------dự đoán cho dòng thứ 335 là 4.6
# ----------dự đoán cho dòng thứ 336 là 0
# ----------dự đoán cho dòng thứ 337 là 5.0
# ----------dự đoán cho dòng thứ 338 là 0
# ----------dự đoán cho dòng thứ 339 là 5.0
# ----------dự đoán cho dòng thứ 340 là 5.0
# ----------dự đoán cho dòng thứ 341 là 5.0
# ----------dự đoán cho dòng thứ 342 là 5.0
# ----------dự đoán cho dòng thứ 343 là 5.0
# ----------dự đoán cho dòng thứ 344 là 0
# ----------dự đoán cho dòng thứ 345 là 0
# ----------dự đoán cho dòng thứ 346 là 0
# ----------dự đoán cho dòng thứ 347 là 5.0
# ----------dự đoán cho dòng thứ 348 là 0
# ----------dự đoán cho dòng thứ 349 là 5.0
# ----------dự đoán cho dòng thứ 350 là 5.0
# ----------dự đoán cho dòng thứ 351 là 0
# ----------dự đoán cho dòng thứ 352 là 5.0
# ----------dự đoán cho dòng thứ 353 là 4.0
# ----------dự đoán cho dòng thứ 354 là 5.0
# ----------dự đoán cho dòng thứ 355 là 5.0
# ----------dự đoán cho dòng thứ 356 là 5.0
# ----------dự đoán cho dòng thứ 357 là 0
# ----------dự đoán cho dòng thứ 358 là 5.0
# ----------dự đoán cho dòng thứ 359 là 5.0
# ----------dự đoán cho dòng thứ 360 là 0
# ----------dự đoán cho dòng thứ 361 là 5.0
# ----------dự đoán cho dòng thứ 362 là 5.0
# ----------dự đoán cho dòng thứ 363 là 0
# ----------dự đoán cho dòng thứ 364 là 1.6666666666666667
# ----------dự đoán cho dòng thứ 365 là 5.0
# ----------dự đoán cho dòng thứ 366 là 5.0
# ----------dự đoán cho dòng thứ 367 là 5.0
# ----------dự đoán cho dòng thứ 368 là 5.0
# ----------dự đoán cho dòng thứ 369 là 0
# ----------dự đoán cho dòng thứ 370 là 5.0
# ----------dự đoán cho dòng thứ 371 là 5.0
# ----------dự đoán cho dòng thứ 372 là 0
# ----------dự đoán cho dòng thứ 373 là 0
# ----------dự đoán cho dòng thứ 374 là 0
# ----------dự đoán cho dòng thứ 375 là 0
# ----------dự đoán cho dòng thứ 376 là 0
# ----------dự đoán cho dòng thứ 377 là 0
# ----------dự đoán cho dòng thứ 378 là 5.0
# ----------dự đoán cho dòng thứ 379 là 0
# ----------dự đoán cho dòng thứ 380 là 0
# ----------dự đoán cho dòng thứ 381 là 0
# ----------dự đoán cho dòng thứ 382 là 0
# ----------dự đoán cho dòng thứ 383 là 5.0
# ----------dự đoán cho dòng thứ 384 là 0
# ----------dự đoán cho dòng thứ 385 là 4.2
# ----------dự đoán cho dòng thứ 386 là 4.972222222222222
# ----------dự đoán cho dòng thứ 387 là 5.0
# ----------dự đoán cho dòng thứ 388 là 5.0
# ----------dự đoán cho dòng thứ 389 là 4.87037037037037
# ----------dự đoán cho dòng thứ 390 là 5.0
# ----------dự đoán cho dòng thứ 391 là 0
# ----------dự đoán cho dòng thứ 392 là 5.0
# ----------dự đoán cho dòng thứ 393 là 0
# ----------dự đoán cho dòng thứ 394 là 0
# ----------dự đoán cho dòng thứ 395 là 0
# ----------dự đoán cho dòng thứ 396 là 0
# ----------dự đoán cho dòng thứ 397 là 5.0
# ----------dự đoán cho dòng thứ 398 là 5.0
# ----------dự đoán cho dòng thứ 399 là 5.0
# ----------dự đoán cho dòng thứ 400 là 0
# ----------dự đoán cho dòng thứ 401 là 5.0
# ----------dự đoán cho dòng thứ 402 là 4.9655172413793105
# ----------dự đoán cho dòng thứ 403 là 5.0
# ----------dự đoán cho dòng thứ 404 là 5.0
# ----------dự đoán cho dòng thứ 405 là 5.0
# ----------dự đoán cho dòng thứ 406 là 4.142857142857143
# ----------dự đoán cho dòng thứ 407 là 0
# ----------dự đoán cho dòng thứ 408 là 5.0
# ----------dự đoán cho dòng thứ 409 là 5.0
# ----------dự đoán cho dòng thứ 410 là 5.0
# ----------dự đoán cho dòng thứ 411 là 5.0
# ----------dự đoán cho dòng thứ 412 là 0
# ----------dự đoán cho dòng thứ 413 là 5.0
# ----------dự đoán cho dòng thứ 414 là 5.0
# ----------dự đoán cho dòng thứ 415 là 4.208333333333333
# ----------dự đoán cho dòng thứ 416 là 0
# ----------dự đoán cho dòng thứ 417 là 4.9375
# ----------dự đoán cho dòng thứ 418 là 5.0
# ----------dự đoán cho dòng thứ 419 là 5.0
# ----------dự đoán cho dòng thứ 420 là 0
# ----------dự đoán cho dòng thứ 421 là 5.0
# ----------dự đoán cho dòng thứ 422 là 5.0
# ----------dự đoán cho dòng thứ 423 là 0
# ----------dự đoán cho dòng thứ 424 là 0
# ----------dự đoán cho dòng thứ 425 là 0
# ----------dự đoán cho dòng thứ 426 là 5.0
# ----------dự đoán cho dòng thứ 427 là 0
# ----------dự đoán cho dòng thứ 428 là 5.0
# ----------dự đoán cho dòng thứ 429 là 4.970588235294118
# ----------dự đoán cho dòng thứ 430 là 4.333333333333333
# ----------dự đoán cho dòng thứ 431 là 0
# ----------dự đoán cho dòng thứ 432 là 5.0
# ----------dự đoán cho dòng thứ 433 là 5.0
# ----------dự đoán cho dòng thứ 434 là 0
# ----------dự đoán cho dòng thứ 435 là 0
# ----------dự đoán cho dòng thứ 436 là 5.0
# ----------dự đoán cho dòng thứ 437 là 0
# ----------dự đoán cho dòng thứ 438 là 0
# ----------dự đoán cho dòng thứ 439 là 0
# ----------dự đoán cho dòng thứ 440 là 5.0
# ----------dự đoán cho dòng thứ 441 là 0
# ----------dự đoán cho dòng thứ 442 là 0
# ----------dự đoán cho dòng thứ 443 là 4.4
# ----------dự đoán cho dòng thứ 444 là 0
# ----------dự đoán cho dòng thứ 445 là 4.5
# ----------dự đoán cho dòng thứ 446 là 5.0
# ----------dự đoán cho dòng thứ 447 là 5.0
# ----------dự đoán cho dòng thứ 448 là 4.5
# ----------dự đoán cho dòng thứ 449 là 5.0
# ----------dự đoán cho dòng thứ 450 là 0
# ----------dự đoán cho dòng thứ 451 là 0
# ----------dự đoán cho dòng thứ 452 là 5.0
# ----------dự đoán cho dòng thứ 453 là 0
# ----------dự đoán cho dòng thứ 454 là 0
# ----------dự đoán cho dòng thứ 455 là 4.666666666666667
# ----------dự đoán cho dòng thứ 456 là 0
# ----------dự đoán cho dòng thứ 457 là 5.0
# ----------dự đoán cho dòng thứ 458 là 0
# ----------dự đoán cho dòng thứ 459 là 0
# ----------dự đoán cho dòng thứ 460 là 0
# ----------dự đoán cho dòng thứ 461 là 4.0
# ----------dự đoán cho dòng thứ 462 là 0
# ----------dự đoán cho dòng thứ 463 là 4.987261146496815
# ----------dự đoán cho dòng thứ 464 là 5.0
# ----------dự đoán cho dòng thứ 465 là 0
# ----------dự đoán cho dòng thứ 466 là 0
# ----------dự đoán cho dòng thứ 467 là 0
# ----------dự đoán cho dòng thứ 468 là 0
# ----------dự đoán cho dòng thứ 469 là 0
# ----------dự đoán cho dòng thứ 470 là 5.0
# ----------dự đoán cho dòng thứ 471 là 0
# ----------dự đoán cho dòng thứ 472 là 5.0
# ----------dự đoán cho dòng thứ 473 là 0
# ----------dự đoán cho dòng thứ 474 là 0
# ----------dự đoán cho dòng thứ 475 là 0
# ----------dự đoán cho dòng thứ 476 là 5.0
# ----------dự đoán cho dòng thứ 477 là 0
# ----------dự đoán cho dòng thứ 478 là 5.0
# ----------dự đoán cho dòng thứ 479 là 5.0
# ----------dự đoán cho dòng thứ 480 là 4.955555555555556
# ----------dự đoán cho dòng thứ 481 là 0
# ----------dự đoán cho dòng thứ 482 là 5.0
# ----------dự đoán cho dòng thứ 483 là 5.0
# ----------dự đoán cho dòng thứ 484 là 0
# ----------dự đoán cho dòng thứ 485 là 0
# ----------dự đoán cho dòng thứ 486 là 5.0
# ----------dự đoán cho dòng thứ 487 là 5.0
# ----------dự đoán cho dòng thứ 488 là 0
# ----------dự đoán cho dòng thứ 489 là 0
# ----------dự đoán cho dòng thứ 490 là 0
# ----------dự đoán cho dòng thứ 491 là 0
# ----------dự đoán cho dòng thứ 492 là 5.0
# ----------dự đoán cho dòng thứ 493 là 5.0
# ----------dự đoán cho dòng thứ 494 là 0
# ----------dự đoán cho dòng thứ 495 là 5.0
# ----------dự đoán cho dòng thứ 496 là 0
# ----------dự đoán cho dòng thứ 497 là 0
# ----------dự đoán cho dòng thứ 498 là 0
# ----------dự đoán cho dòng thứ 499 là 5.0
# ----------dự đoán cho dòng thứ 500 là 4.0
# ----------dự đoán cho dòng thứ 501 là 5.0
# ----------dự đoán cho dòng thứ 502 là 4.0
# ----------dự đoán cho dòng thứ 503 là 5.0
# ----------dự đoán cho dòng thứ 504 là 0
# ----------dự đoán cho dòng thứ 505 là 0
# ----------dự đoán cho dòng thứ 506 là 0
# ----------dự đoán cho dòng thứ 507 là 5.0
# ----------dự đoán cho dòng thứ 508 là 0
# ----------dự đoán cho dòng thứ 509 là 5.0
# ----------dự đoán cho dòng thứ 510 là 0
# ----------dự đoán cho dòng thứ 511 là 0
# ----------dự đoán cho dòng thứ 512 là 0
# ----------dự đoán cho dòng thứ 513 là 4.991150442477876
# ----------dự đoán cho dòng thứ 514 là 0
# ----------dự đoán cho dòng thứ 515 là 4.0
# ----------dự đoán cho dòng thứ 516 là 0
# ----------dự đoán cho dòng thứ 517 là 5.0
# ----------dự đoán cho dòng thứ 518 là 5.0
# ----------dự đoán cho dòng thứ 519 là 0
# ----------dự đoán cho dòng thứ 520 là 0
# ----------dự đoán cho dòng thứ 521 là 4.888111888111888
# ----------dự đoán cho dòng thứ 522 là 0
# ----------dự đoán cho dòng thứ 523 là 0
# ----------dự đoán cho dòng thứ 524 là 0
# ----------dự đoán cho dòng thứ 525 là 5.0
# ----------dự đoán cho dòng thứ 526 là 4.0
# ----------dự đoán cho dòng thứ 527 là 5.0
# ----------dự đoán cho dòng thứ 528 là 5.0
# ----------dự đoán cho dòng thứ 529 là 0
# ----------dự đoán cho dòng thứ 530 là 0
# ----------dự đoán cho dòng thứ 531 là 5.0
# ----------dự đoán cho dòng thứ 532 là 0
# ----------dự đoán cho dòng thứ 533 là 5.0
# ----------dự đoán cho dòng thứ 534 là 5.0
# ----------dự đoán cho dòng thứ 535 là 4.0
# ----------dự đoán cho dòng thứ 536 là 0
# ----------dự đoán cho dòng thứ 537 là 5.0
# ----------dự đoán cho dòng thứ 538 là 5.0
# ----------dự đoán cho dòng thứ 539 là 5.0
# ----------dự đoán cho dòng thứ 540 là 0
# ----------dự đoán cho dòng thứ 541 là 0
# ----------dự đoán cho dòng thứ 542 là 5.0
# ----------dự đoán cho dòng thứ 543 là 0
# ----------dự đoán cho dòng thứ 544 là 4.666666666666667
# ----------dự đoán cho dòng thứ 545 là 0
# ----------dự đoán cho dòng thứ 546 là 0
# ----------dự đoán cho dòng thứ 547 là 0
# ----------dự đoán cho dòng thứ 548 là 0
# ----------dự đoán cho dòng thứ 549 là 0
# ----------dự đoán cho dòng thứ 550 là 0
# ----------dự đoán cho dòng thứ 551 là 5.0
# ----------dự đoán cho dòng thứ 552 là 4.375
# ----------dự đoán cho dòng thứ 553 là 0
# ----------dự đoán cho dòng thứ 554 là 5.0
# ----------dự đoán cho dòng thứ 555 là 4.105263157894737
# ----------dự đoán cho dòng thứ 556 là 0
# ----------dự đoán cho dòng thứ 557 là 0
# ----------dự đoán cho dòng thứ 558 là 5.0
# ----------dự đoán cho dòng thứ 559 là 5.0
# ----------dự đoán cho dòng thứ 560 là 0
# ----------dự đoán cho dòng thứ 561 là 0
# ----------dự đoán cho dòng thứ 562 là 0
# ----------dự đoán cho dòng thứ 563 là 4.0
# ----------dự đoán cho dòng thứ 564 là 5.0
# ----------dự đoán cho dòng thứ 565 là 5.0
# ----------dự đoán cho dòng thứ 566 là 0
# ----------dự đoán cho dòng thứ 567 là 0
# ----------dự đoán cho dòng thứ 568 là 5.0
# ----------dự đoán cho dòng thứ 569 là 0
# ----------dự đoán cho dòng thứ 570 là 0
# ----------dự đoán cho dòng thứ 571 là 5.0
# ----------dự đoán cho dòng thứ 572 là 0
# ----------dự đoán cho dòng thứ 573 là 5.0
# ----------dự đoán cho dòng thứ 574 là 0
# ----------dự đoán cho dòng thứ 575 là 5.0
# ----------dự đoán cho dòng thứ 576 là 0
# ----------dự đoán cho dòng thứ 577 là 0
# ----------dự đoán cho dòng thứ 578 là 0
# ----------dự đoán cho dòng thứ 579 là 5.0
# ----------dự đoán cho dòng thứ 580 là 5.0
# ----------dự đoán cho dòng thứ 581 là 4.0
# ----------dự đoán cho dòng thứ 582 là 0
# ----------dự đoán cho dòng thứ 583 là 0
# ----------dự đoán cho dòng thứ 584 là 0
# ----------dự đoán cho dòng thứ 585 là 0
# ----------dự đoán cho dòng thứ 586 là 4.666666666666667
# ----------dự đoán cho dòng thứ 587 là 5.0
# ----------dự đoán cho dòng thứ 588 là 5.0
# ----------dự đoán cho dòng thứ 589 là 0
# ----------dự đoán cho dòng thứ 590 là 5.0
# ----------dự đoán cho dòng thứ 591 là 0
# ----------dự đoán cho dòng thứ 592 là 0
# ----------dự đoán cho dòng thứ 593 là 0
# ----------dự đoán cho dòng thứ 594 là 0
# ----------dự đoán cho dòng thứ 595 là 0
# ----------dự đoán cho dòng thứ 596 là 0
# ----------dự đoán cho dòng thứ 597 là 5.0
# ----------dự đoán cho dòng thứ 598 là 0
# ----------dự đoán cho dòng thứ 599 là 0
# ----------dự đoán cho dòng thứ 600 là 5.0
# ----------dự đoán cho dòng thứ 601 là 0
# ----------dự đoán cho dòng thứ 602 là 0
# ----------dự đoán cho dòng thứ 603 là 5.0
# ----------dự đoán cho dòng thứ 604 là 4.875
# ----------dự đoán cho dòng thứ 605 là 0
# ----------dự đoán cho dòng thứ 606 là 0
# ----------dự đoán cho dòng thứ 607 là 5.0
# ----------dự đoán cho dòng thứ 608 là 0
# ----------dự đoán cho dòng thứ 609 là 0
# ----------dự đoán cho dòng thứ 610 là 0
# ----------dự đoán cho dòng thứ 611 là 0
# ----------dự đoán cho dòng thứ 612 là 5.0
# ----------dự đoán cho dòng thứ 613 là 5.0
# ----------dự đoán cho dòng thứ 614 là 5.0
# ----------dự đoán cho dòng thứ 615 là 0
# ----------dự đoán cho dòng thứ 616 là 5.0
# ----------dự đoán cho dòng thứ 617 là 5.0
# ----------dự đoán cho dòng thứ 618 là 0
# ----------dự đoán cho dòng thứ 619 là 0
# ----------dự đoán cho dòng thứ 620 là 5.0
# ----------dự đoán cho dòng thứ 621 là 0
# ----------dự đoán cho dòng thứ 622 là 0
# ----------dự đoán cho dòng thứ 623 là 5.0
# ----------dự đoán cho dòng thứ 624 là 5.0
# ----------dự đoán cho dòng thứ 625 là 0
# ----------dự đoán cho dòng thứ 626 là 5.0
# ----------dự đoán cho dòng thứ 627 là 5.0
# ----------dự đoán cho dòng thứ 628 là 5.0
# ----------dự đoán cho dòng thứ 629 là 0
# ----------dự đoán cho dòng thứ 630 là 0
# ----------dự đoán cho dòng thứ 631 là 0
# ----------dự đoán cho dòng thứ 632 là 0
# ----------dự đoán cho dòng thứ 633 là 4.0
# ----------dự đoán cho dòng thứ 634 là 5.0
# ----------dự đoán cho dòng thứ 635 là 0
# ----------dự đoán cho dòng thứ 636 là 0
# ----------dự đoán cho dòng thứ 637 là 0
# ----------dự đoán cho dòng thứ 638 là 5.0
# ----------dự đoán cho dòng thứ 639 là 0
# ----------dự đoán cho dòng thứ 640 là 5.0
# ----------dự đoán cho dòng thứ 641 là 0
# ----------dự đoán cho dòng thứ 642 là 0
# ----------dự đoán cho dòng thứ 643 là 5.0
# ----------dự đoán cho dòng thứ 644 là 0
# ----------dự đoán cho dòng thứ 645 là 5.0
# ----------dự đoán cho dòng thứ 646 là 4.823529411764706
# ----------dự đoán cho dòng thứ 647 là 5.0
# ----------dự đoán cho dòng thứ 648 là 5.0
# ----------dự đoán cho dòng thứ 649 là 5.0
# ----------dự đoán cho dòng thứ 650 là 0
# ----------dự đoán cho dòng thứ 651 là 5.0
# ----------dự đoán cho dòng thứ 652 là 4.625
# ----------dự đoán cho dòng thứ 653 là 5.0
# ----------dự đoán cho dòng thứ 654 là 4.0
# ----------dự đoán cho dòng thứ 655 là 5.0
# ----------dự đoán cho dòng thứ 656 là 0
# ----------dự đoán cho dòng thứ 657 là 0
# ----------dự đoán cho dòng thứ 658 là 3.5714285714285716
# ----------dự đoán cho dòng thứ 659 là 5.0
# ----------dự đoán cho dòng thứ 660 là 0
# ----------dự đoán cho dòng thứ 661 là 0
# ----------dự đoán cho dòng thứ 662 là 5.0
# ----------dự đoán cho dòng thứ 663 là 0
# ----------dự đoán cho dòng thứ 664 là 0
# ----------dự đoán cho dòng thứ 665 là 5.0
# ----------dự đoán cho dòng thứ 666 là 5.0
# ----------dự đoán cho dòng thứ 667 là 0
# ----------dự đoán cho dòng thứ 668 là 0
# ----------dự đoán cho dòng thứ 669 là 0
# ----------dự đoán cho dòng thứ 670 là 0
# ----------dự đoán cho dòng thứ 671 là 0
# ----------dự đoán cho dòng thứ 672 là 5.0
# ----------dự đoán cho dòng thứ 673 là 5.0
# ----------dự đoán cho dòng thứ 674 là 0
# ----------dự đoán cho dòng thứ 675 là 3.0
# ----------dự đoán cho dòng thứ 676 là 0
# ----------dự đoán cho dòng thứ 677 là 5.0
# ----------dự đoán cho dòng thứ 678 là 0
# ----------dự đoán cho dòng thứ 679 là 5.0
# ----------dự đoán cho dòng thứ 680 là 5.0
# ----------dự đoán cho dòng thứ 681 là 4.980036297640654
# ----------dự đoán cho dòng thứ 682 là 0
# ----------dự đoán cho dòng thứ 683 là 0
# ----------dự đoán cho dòng thứ 684 là 5.0
# ----------dự đoán cho dòng thứ 685 là 0
# ----------dự đoán cho dòng thứ 686 là 0
# ----------dự đoán cho dòng thứ 687 là 5.0
# ----------dự đoán cho dòng thứ 688 là 0
# ----------dự đoán cho dòng thứ 689 là 5.0
# ----------dự đoán cho dòng thứ 690 là 0
# ----------dự đoán cho dòng thứ 691 là 0
# ----------dự đoán cho dòng thứ 692 là 5.0
# ----------dự đoán cho dòng thứ 693 là 0
# ----------dự đoán cho dòng thứ 694 là 0
# ----------dự đoán cho dòng thứ 695 là 4.940298507462686
# ----------dự đoán cho dòng thứ 696 là 5.0
# ----------dự đoán cho dòng thứ 697 là 4.666666666666667
# ----------dự đoán cho dòng thứ 698 là 5.0
# ----------dự đoán cho dòng thứ 699 là 0
# ----------dự đoán cho dòng thứ 700 là 4.714285714285714
# ----------dự đoán cho dòng thứ 701 là 0
# ----------dự đoán cho dòng thứ 702 là 5.0
# ----------dự đoán cho dòng thứ 703 là 5.0
# ----------dự đoán cho dòng thứ 704 là 5.0
# ----------dự đoán cho dòng thứ 705 là 5.0
# ----------dự đoán cho dòng thứ 706 là 4.8
# ----------dự đoán cho dòng thứ 707 là 0
# ----------dự đoán cho dòng thứ 708 là 5.0
# ----------dự đoán cho dòng thứ 709 là 0
# ----------dự đoán cho dòng thứ 710 là 0
# ----------dự đoán cho dòng thứ 711 là 5.0
# ----------dự đoán cho dòng thứ 712 là 0
# ----------dự đoán cho dòng thứ 713 là 5.0
# ----------dự đoán cho dòng thứ 714 là 0
# ----------dự đoán cho dòng thứ 715 là 5.0
# ----------dự đoán cho dòng thứ 716 là 5.0
# ----------dự đoán cho dòng thứ 717 là 4.966666666666667
# ----------dự đoán cho dòng thứ 718 là 0
# ----------dự đoán cho dòng thứ 719 là 0
# ----------dự đoán cho dòng thứ 720 là 4.666666666666667
# ----------dự đoán cho dòng thứ 721 là 0
# ----------dự đoán cho dòng thứ 722 là 5.0
# ----------dự đoán cho dòng thứ 723 là 5.0
# ----------dự đoán cho dòng thứ 724 là 5.0
# ----------dự đoán cho dòng thứ 725 là 0
# ----------dự đoán cho dòng thứ 726 là 5.0
# ----------dự đoán cho dòng thứ 727 là 5.0
# ----------dự đoán cho dòng thứ 728 là 0
# ----------dự đoán cho dòng thứ 729 là 0
# ----------dự đoán cho dòng thứ 730 là 0
# ----------dự đoán cho dòng thứ 731 là 5.0
# ----------dự đoán cho dòng thứ 732 là 5.0
# ----------dự đoán cho dòng thứ 733 là 4.963636363636364
# ----------dự đoán cho dòng thứ 734 là 0
# ----------dự đoán cho dòng thứ 735 là 5.0
# ----------dự đoán cho dòng thứ 736 là 5.0
# ----------dự đoán cho dòng thứ 737 là 4.753623188405797
# ----------dự đoán cho dòng thứ 738 là 0
# ----------dự đoán cho dòng thứ 739 là 5.0
# ----------dự đoán cho dòng thứ 740 là 4.964285714285714
# ----------dự đoán cho dòng thứ 741 là 5.0
# ----------dự đoán cho dòng thứ 742 là 0
# ----------dự đoán cho dòng thứ 743 là 0
# ----------dự đoán cho dòng thứ 744 là 5.0
# ----------dự đoán cho dòng thứ 745 là 5.0
# ----------dự đoán cho dòng thứ 746 là 5.0
# ----------dự đoán cho dòng thứ 747 là 5.0
# ----------dự đoán cho dòng thứ 748 là 5.0
# ----------dự đoán cho dòng thứ 749 là 0
# ----------dự đoán cho dòng thứ 750 là 0
# ----------dự đoán cho dòng thứ 751 là 0
# ----------dự đoán cho dòng thứ 752 là 4.714285714285714
# ----------dự đoán cho dòng thứ 753 là 4.75
# ----------dự đoán cho dòng thứ 754 là 5.0
# ----------dự đoán cho dòng thứ 755 là 0
# ----------dự đoán cho dòng thứ 756 là 5.0
# ----------dự đoán cho dòng thứ 757 là 0
# ----------dự đoán cho dòng thứ 758 là 5.0
# ----------dự đoán cho dòng thứ 759 là 5.0
# ----------dự đoán cho dòng thứ 760 là 0
# ----------dự đoán cho dòng thứ 761 là 0
# ----------dự đoán cho dòng thứ 762 là 0
# ----------dự đoán cho dòng thứ 763 là 5.0
# ----------dự đoán cho dòng thứ 764 là 5.0
# ----------dự đoán cho dòng thứ 765 là 0
# ----------dự đoán cho dòng thứ 766 là 5.0
# ----------dự đoán cho dòng thứ 767 là 5.0
# ----------dự đoán cho dòng thứ 768 là 5.0
# ----------dự đoán cho dòng thứ 769 là 0
# ----------dự đoán cho dòng thứ 770 là 3.6666666666666665
# ----------dự đoán cho dòng thứ 771 là 0
# ----------dự đoán cho dòng thứ 772 là 0
# ----------dự đoán cho dòng thứ 773 là 0
# ----------dự đoán cho dòng thứ 774 là 0
# ----------dự đoán cho dòng thứ 775 là 0
# ----------dự đoán cho dòng thứ 776 là 0
# ----------dự đoán cho dòng thứ 777 là 0
# ----------dự đoán cho dòng thứ 778 là 5.0
# ----------dự đoán cho dòng thứ 779 là 5.0
# ----------dự đoán cho dòng thứ 780 là 5.0
# ----------dự đoán cho dòng thứ 781 là 0
# ----------dự đoán cho dòng thứ 782 là 5.0
# ----------dự đoán cho dòng thứ 783 là 0
# ----------dự đoán cho dòng thứ 784 là 4.0
# ----------dự đoán cho dòng thứ 785 là 5.0
# ----------dự đoán cho dòng thứ 786 là 0
# ----------dự đoán cho dòng thứ 787 là 0
# ----------dự đoán cho dòng thứ 788 là 0
# ----------dự đoán cho dòng thứ 789 là 0
# ----------dự đoán cho dòng thứ 790 là 5.0
# ----------dự đoán cho dòng thứ 791 là 0
# ----------dự đoán cho dòng thứ 792 là 5.0
# ----------dự đoán cho dòng thứ 793 là 5.0
# ----------dự đoán cho dòng thứ 794 là 0
# ----------dự đoán cho dòng thứ 795 là 3.769230769230769
# ----------dự đoán cho dòng thứ 796 là 0
# ----------dự đoán cho dòng thứ 797 là 0
# ----------dự đoán cho dòng thứ 798 là 0
# ----------dự đoán cho dòng thứ 799 là 0
# ----------dự đoán cho dòng thứ 800 là 5.0
# ----------dự đoán cho dòng thứ 801 là 5.0
# ----------dự đoán cho dòng thứ 802 là 0
# ----------dự đoán cho dòng thứ 803 là 5.0
# ----------dự đoán cho dòng thứ 804 là 0
# ----------dự đoán cho dòng thứ 805 là 5.0
# ----------dự đoán cho dòng thứ 806 là 0
# ----------dự đoán cho dòng thứ 807 là 0
# ----------dự đoán cho dòng thứ 808 là 5.0
# ----------dự đoán cho dòng thứ 809 là 0
# ----------dự đoán cho dòng thứ 810 là 0
# ----------dự đoán cho dòng thứ 811 là 5.0
# ----------dự đoán cho dòng thứ 812 là 3.0
# ----------dự đoán cho dòng thứ 813 là 5.0
# ----------dự đoán cho dòng thứ 814 là 0
# ----------dự đoán cho dòng thứ 815 là 0
# ----------dự đoán cho dòng thứ 816 là 4.0
# ----------dự đoán cho dòng thứ 817 là 5.0
# ----------dự đoán cho dòng thứ 818 là 0
# ----------dự đoán cho dòng thứ 819 là 5.0
# ----------dự đoán cho dòng thứ 820 là 5.0
# ----------dự đoán cho dòng thứ 821 là 5.0
# ----------dự đoán cho dòng thứ 822 là 0
# ----------dự đoán cho dòng thứ 823 là 3.0
# ----------dự đoán cho dòng thứ 824 là 0
# ----------dự đoán cho dòng thứ 825 là 0
# ----------dự đoán cho dòng thứ 826 là 5.0
# ----------dự đoán cho dòng thứ 827 là 0
# ----------dự đoán cho dòng thứ 828 là 0
# ----------dự đoán cho dòng thứ 829 là 5.0
# ----------dự đoán cho dòng thứ 830 là 0
# ----------dự đoán cho dòng thứ 831 là 5.0
# ----------dự đoán cho dòng thứ 832 là 4.8
# ----------dự đoán cho dòng thứ 833 là 5.0
# ----------dự đoán cho dòng thứ 834 là 5.0
# ----------dự đoán cho dòng thứ 835 là 4.5
# ----------dự đoán cho dòng thứ 836 là 5.0
# ----------dự đoán cho dòng thứ 837 là 0
# ----------dự đoán cho dòng thứ 838 là 0
# ----------dự đoán cho dòng thứ 839 là 5.0
# ----------dự đoán cho dòng thứ 840 là 0
# ----------dự đoán cho dòng thứ 841 là 5.0
# ----------dự đoán cho dòng thứ 842 là 0
# ----------dự đoán cho dòng thứ 843 là 0
# ----------dự đoán cho dòng thứ 844 là 0
# ----------dự đoán cho dòng thứ 845 là 5.0
# ----------dự đoán cho dòng thứ 846 là 5.0
# ----------dự đoán cho dòng thứ 847 là 0
# ----------dự đoán cho dòng thứ 848 là 5.0
# ----------dự đoán cho dòng thứ 849 là 5.0
# ----------dự đoán cho dòng thứ 850 là 0
# ----------dự đoán cho dòng thứ 851 là 5.0
# ----------dự đoán cho dòng thứ 852 là 5.0
# ----------dự đoán cho dòng thứ 853 là 4.714285714285714
# ----------dự đoán cho dòng thứ 854 là 5.0
# ----------dự đoán cho dòng thứ 855 là 5.0
# ----------dự đoán cho dòng thứ 856 là 0
# ----------dự đoán cho dòng thứ 857 là 5.0
# ----------dự đoán cho dòng thứ 858 là 0
# ----------dự đoán cho dòng thứ 859 là 0
# ----------dự đoán cho dòng thứ 860 là 5.0
# ----------dự đoán cho dòng thứ 861 là 5.0
# ----------dự đoán cho dòng thứ 862 là 5.0
# ----------dự đoán cho dòng thứ 863 là 0
# ----------dự đoán cho dòng thứ 864 là 5.0
# ----------dự đoán cho dòng thứ 865 là 5.0
# ----------dự đoán cho dòng thứ 866 là 0
# ----------dự đoán cho dòng thứ 867 là 0
# ----------dự đoán cho dòng thứ 868 là 0
# ----------dự đoán cho dòng thứ 869 là 5.0
# ----------dự đoán cho dòng thứ 870 là 0
# ----------dự đoán cho dòng thứ 871 là 5.0
# ----------dự đoán cho dòng thứ 872 là 5.0
# ----------dự đoán cho dòng thứ 873 là 5.0
# ----------dự đoán cho dòng thứ 874 là 0
# ----------dự đoán cho dòng thứ 875 là 5.0
# ----------dự đoán cho dòng thứ 876 là 5.0
# ----------dự đoán cho dòng thứ 877 là 0
# ----------dự đoán cho dòng thứ 878 là 0
# ----------dự đoán cho dòng thứ 879 là 0
# ----------dự đoán cho dòng thứ 880 là 5.0
# ----------dự đoán cho dòng thứ 881 là 5.0
# ----------dự đoán cho dòng thứ 882 là 3.0
# ----------dự đoán cho dòng thứ 883 là 0
# ----------dự đoán cho dòng thứ 884 là 0
# ----------dự đoán cho dòng thứ 885 là 5.0
# ----------dự đoán cho dòng thứ 886 là 0
# ----------dự đoán cho dòng thứ 887 là 0
# ----------dự đoán cho dòng thứ 888 là 0
# ----------dự đoán cho dòng thứ 889 là 5.0
# ----------dự đoán cho dòng thứ 890 là 4.7
# ----------dự đoán cho dòng thứ 891 là 0
# ----------dự đoán cho dòng thứ 892 là 4.6
# ----------dự đoán cho dòng thứ 893 là 5.0
# ----------dự đoán cho dòng thứ 894 là 0
# ----------dự đoán cho dòng thứ 895 là 0
# ----------dự đoán cho dòng thứ 896 là 0
# ----------dự đoán cho dòng thứ 897 là 5.0
# ----------dự đoán cho dòng thứ 898 là 0
# ----------dự đoán cho dòng thứ 899 là 0
# ----------dự đoán cho dòng thứ 900 là 5.0
# ----------dự đoán cho dòng thứ 901 là 5.0
# ----------dự đoán cho dòng thứ 902 là 5.0
# ----------dự đoán cho dòng thứ 903 là 5.0
# ----------dự đoán cho dòng thứ 904 là 3.2857142857142856
# ----------dự đoán cho dòng thứ 905 là 0
# ----------dự đoán cho dòng thứ 906 là 5.0
# ----------dự đoán cho dòng thứ 907 là 5.0
# ----------dự đoán cho dòng thứ 908 là 5.0
# ----------dự đoán cho dòng thứ 909 là 5.0
# ----------dự đoán cho dòng thứ 910 là 5.0
# ----------dự đoán cho dòng thứ 911 là 5.0
# ----------dự đoán cho dòng thứ 912 là 5.0
# ----------dự đoán cho dòng thứ 913 là 0
# ----------dự đoán cho dòng thứ 914 là 0
# ----------dự đoán cho dòng thứ 915 là 5.0
# ----------dự đoán cho dòng thứ 916 là 0
# ----------dự đoán cho dòng thứ 917 là 5.0
# ----------dự đoán cho dòng thứ 918 là 0
# ----------dự đoán cho dòng thứ 919 là 5.0
# ----------dự đoán cho dòng thứ 920 là 5.0
# ----------dự đoán cho dòng thứ 921 là 0
# ----------dự đoán cho dòng thứ 922 là 0
# ----------dự đoán cho dòng thứ 923 là 0
# ----------dự đoán cho dòng thứ 924 là 5.0
# ----------dự đoán cho dòng thứ 925 là 0
# ----------dự đoán cho dòng thứ 926 là 5.0
# ----------dự đoán cho dòng thứ 927 là 5.0
# ----------dự đoán cho dòng thứ 928 là 5.0
# ----------dự đoán cho dòng thứ 929 là 0
# ----------dự đoán cho dòng thứ 930 là 5.0
# ----------dự đoán cho dòng thứ 931 là 0
# ----------dự đoán cho dòng thứ 932 là 5.0
# ----------dự đoán cho dòng thứ 933 là 0
# ----------dự đoán cho dòng thứ 934 là 0
# ----------dự đoán cho dòng thứ 935 là 0
# ----------dự đoán cho dòng thứ 936 là 0
# ----------dự đoán cho dòng thứ 937 là 0
# ----------dự đoán cho dòng thứ 938 là 5.0
# ----------dự đoán cho dòng thứ 939 là 0
# ----------dự đoán cho dòng thứ 940 là 5.0
# ----------dự đoán cho dòng thứ 941 là 0
# ----------dự đoán cho dòng thứ 942 là 0
# ----------dự đoán cho dòng thứ 943 là 0
# ----------dự đoán cho dòng thứ 944 là 0
# ----------dự đoán cho dòng thứ 945 là 0
# ----------dự đoán cho dòng thứ 946 là 5.0
# ----------dự đoán cho dòng thứ 947 là 5.0
# ----------dự đoán cho dòng thứ 948 là 5.0
# ----------dự đoán cho dòng thứ 949 là 5.0
# ----------dự đoán cho dòng thứ 950 là 0
# ----------dự đoán cho dòng thứ 951 là 0
# ----------dự đoán cho dòng thứ 952 là 5.0
# ----------dự đoán cho dòng thứ 953 là 0
# ----------dự đoán cho dòng thứ 954 là 0
# ----------dự đoán cho dòng thứ 955 là 0
# ----------dự đoán cho dòng thứ 956 là 0
# ----------dự đoán cho dòng thứ 957 là 5.0
# ----------dự đoán cho dòng thứ 958 là 5.0
# ----------dự đoán cho dòng thứ 959 là 0
# ----------dự đoán cho dòng thứ 960 là 5.0
# ----------dự đoán cho dòng thứ 961 là 5.0
# ----------dự đoán cho dòng thứ 962 là 5.0
# ----------dự đoán cho dòng thứ 963 là 0
# ----------dự đoán cho dòng thứ 964 là 5.0
# ----------dự đoán cho dòng thứ 965 là 5.0
# ----------dự đoán cho dòng thứ 966 là 0
# ----------dự đoán cho dòng thứ 967 là 5.0
# ----------dự đoán cho dòng thứ 968 là 5.0
# ----------dự đoán cho dòng thứ 969 là 5.0
# ----------dự đoán cho dòng thứ 970 là 5.0
# ----------dự đoán cho dòng thứ 971 là 0
# ----------dự đoán cho dòng thứ 972 là 5.0
# ----------dự đoán cho dòng thứ 973 là 0
# ----------dự đoán cho dòng thứ 974 là 0
# ----------dự đoán cho dòng thứ 975 là 5.0
# ----------dự đoán cho dòng thứ 976 là 5.0
# ----------dự đoán cho dòng thứ 977 là 5.0
# ----------dự đoán cho dòng thứ 978 là 0
# ----------dự đoán cho dòng thứ 979 là 5.0
# ----------dự đoán cho dòng thứ 980 là 5.0
# ----------dự đoán cho dòng thứ 981 là 5.0
# ----------dự đoán cho dòng thứ 982 là 0
# ----------dự đoán cho dòng thứ 983 là 0
# ----------dự đoán cho dòng thứ 984 là 5.0
# ----------dự đoán cho dòng thứ 985 là 4.955555555555556
# ----------dự đoán cho dòng thứ 986 là 0
# ----------dự đoán cho dòng thứ 987 là 0
# ----------dự đoán cho dòng thứ 988 là 4.25
# ----------dự đoán cho dòng thứ 989 là 0
# ----------dự đoán cho dòng thứ 990 là 0
# ----------dự đoán cho dòng thứ 991 là 0
# ----------dự đoán cho dòng thứ 992 là 5.0
# ----------dự đoán cho dòng thứ 993 là 0
# ----------dự đoán cho dòng thứ 994 là 5.0
# ----------dự đoán cho dòng thứ 995 là 5.0
# ----------dự đoán cho dòng thứ 996 là 4.5
# ----------dự đoán cho dòng thứ 997 là 4.75
# ----------dự đoán cho dòng thứ 998 là 0
# ----------dự đoán cho dòng thứ 999 là 0
# ----------dự đoán cho dòng thứ 1000 là 4.957446808510638
# ----------dự đoán cho dòng thứ 1001 là 5.0
# ----------dự đoán cho dòng thứ 1002 là 4.9655172413793105
# ----------dự đoán cho dòng thứ 1003 là 5.0
# ----------dự đoán cho dòng thứ 1004 là 5.0
# ----------dự đoán cho dòng thứ 1005 là 0
# ----------dự đoán cho dòng thứ 1006 là 5.0
# ----------dự đoán cho dòng thứ 1007 là 0
# ----------dự đoán cho dòng thứ 1008 là 0
# ----------dự đoán cho dòng thứ 1009 là 0
# ----------dự đoán cho dòng thứ 1010 là 4.0
# ----------dự đoán cho dòng thứ 1011 là 0
# ----------dự đoán cho dòng thứ 1012 là 0
# ----------dự đoán cho dòng thứ 1013 là 4.0
# ----------dự đoán cho dòng thứ 1014 là 0
# ----------dự đoán cho dòng thứ 1015 là 0
# ----------dự đoán cho dòng thứ 1016 là 0
# ----------dự đoán cho dòng thứ 1017 là 5.0
# ----------dự đoán cho dòng thứ 1018 là 0
# ----------dự đoán cho dòng thứ 1019 là 5.0
# ----------dự đoán cho dòng thứ 1020 là 0
# ----------dự đoán cho dòng thứ 1021 là 0
# ----------dự đoán cho dòng thứ 1022 là 5.0
# ----------dự đoán cho dòng thứ 1023 là 5.0
# ----------dự đoán cho dòng thứ 1024 là 0
# ----------dự đoán cho dòng thứ 1025 là 5.0
# ----------dự đoán cho dòng thứ 1026 là 0
# ----------dự đoán cho dòng thứ 1027 là 5.0
# ----------dự đoán cho dòng thứ 1028 là 0
# ----------dự đoán cho dòng thứ 1029 là 5.0
# ----------dự đoán cho dòng thứ 1030 là 5.0
# ----------dự đoán cho dòng thứ 1031 là 3.6666666666666665
# ----------dự đoán cho dòng thứ 1032 là 0
# ----------dự đoán cho dòng thứ 1033 là 0
# ----------dự đoán cho dòng thứ 1034 là 5.0
# ----------dự đoán cho dòng thứ 1035 là 0
# ----------dự đoán cho dòng thứ 1036 là 0
# ----------dự đoán cho dòng thứ 1037 là 5.0
# ----------dự đoán cho dòng thứ 1038 là 5.0
# ----------dự đoán cho dòng thứ 1039 là 0
# ----------dự đoán cho dòng thứ 1040 là 0
# ----------dự đoán cho dòng thứ 1041 là 5.0
# ----------dự đoán cho dòng thứ 1042 là 5.0
# ----------dự đoán cho dòng thứ 1043 là 0
# ----------dự đoán cho dòng thứ 1044 là 0
# ----------dự đoán cho dòng thứ 1045 là 5.0
# ----------dự đoán cho dòng thứ 1046 là 0
# ----------dự đoán cho dòng thứ 1047 là 5.0
# ----------dự đoán cho dòng thứ 1048 là 5.0
# ----------dự đoán cho dòng thứ 1049 là 0
# ----------dự đoán cho dòng thứ 1050 là 0
# ----------dự đoán cho dòng thứ 1051 là 0
# ----------dự đoán cho dòng thứ 1052 là 4.5
# ----------dự đoán cho dòng thứ 1053 là 0
# ----------dự đoán cho dòng thứ 1054 là 0
# ----------dự đoán cho dòng thứ 1055 là 0
# ----------dự đoán cho dòng thứ 1056 là 0
# ----------dự đoán cho dòng thứ 1057 là 0
# ----------dự đoán cho dòng thứ 1058 là 5.0
# ----------dự đoán cho dòng thứ 1059 là 4.0
# ----------dự đoán cho dòng thứ 1060 là 5.0
# ----------dự đoán cho dòng thứ 1061 là 3.0
# ----------dự đoán cho dòng thứ 1062 là 5.0
# ----------dự đoán cho dòng thứ 1063 là 0
# ----------dự đoán cho dòng thứ 1064 là 5.0
# ----------dự đoán cho dòng thứ 1065 là 0
# ----------dự đoán cho dòng thứ 1066 là 5.0
# ----------dự đoán cho dòng thứ 1067 là 5.0
# ----------dự đoán cho dòng thứ 1068 là 4.25
# ----------dự đoán cho dòng thứ 1069 là 0
# ----------dự đoán cho dòng thứ 1070 là 5.0
# ----------dự đoán cho dòng thứ 1071 là 5.0
# ----------dự đoán cho dòng thứ 1072 là 0
# ----------dự đoán cho dòng thứ 1073 là 0
# ----------dự đoán cho dòng thứ 1074 là 5.0
# ----------dự đoán cho dòng thứ 1075 là 0
# ----------dự đoán cho dòng thứ 1076 là 5.0
# ----------dự đoán cho dòng thứ 1077 là 0
# ----------dự đoán cho dòng thứ 1078 là 0
# ----------dự đoán cho dòng thứ 1079 là 5.0
# ----------dự đoán cho dòng thứ 1080 là 5.0
# ----------dự đoán cho dòng thứ 1081 là 5.0
# ----------dự đoán cho dòng thứ 1082 là 4.2
# ----------dự đoán cho dòng thứ 1083 là 5.0
# ----------dự đoán cho dòng thứ 1084 là 0
# ----------dự đoán cho dòng thứ 1085 là 5.0
# ----------dự đoán cho dòng thứ 1086 là 5.0
# ----------dự đoán cho dòng thứ 1087 là 5.0
# ----------dự đoán cho dòng thứ 1088 là 0
# ----------dự đoán cho dòng thứ 1089 là 5.0
# ----------dự đoán cho dòng thứ 1090 là 0
# ----------dự đoán cho dòng thứ 1091 là 0
# ----------dự đoán cho dòng thứ 1092 là 5.0
# ----------dự đoán cho dòng thứ 1093 là 0
# ----------dự đoán cho dòng thứ 1094 là 0
# ----------dự đoán cho dòng thứ 1095 là 5.0
# ----------dự đoán cho dòng thứ 1096 là 5.0
# ----------dự đoán cho dòng thứ 1097 là 5.0
# ----------dự đoán cho dòng thứ 1098 là 0
# ----------dự đoán cho dòng thứ 1099 là 5.0
# ----------dự đoán cho dòng thứ 1100 là 5.0
# ----------dự đoán cho dòng thứ 1101 là 0
# ----------dự đoán cho dòng thứ 1102 là 0
# ----------dự đoán cho dòng thứ 1103 là 5.0
# ----------dự đoán cho dòng thứ 1104 là 4.86
# ----------dự đoán cho dòng thứ 1105 là 4.930232558139535
# ----------dự đoán cho dòng thứ 1106 là 0
# ----------dự đoán cho dòng thứ 1107 là 0
# ----------dự đoán cho dòng thứ 1108 là 5.0
# ----------dự đoán cho dòng thứ 1109 là 5.0
# ----------dự đoán cho dòng thứ 1110 là 5.0
# ----------dự đoán cho dòng thứ 1111 là 0
# ----------dự đoán cho dòng thứ 1112 là 5.0
# ----------dự đoán cho dòng thứ 1113 là 5.0
# ----------dự đoán cho dòng thứ 1114 là 5.0
# ----------dự đoán cho dòng thứ 1115 là 5.0
# ----------dự đoán cho dòng thứ 1116 là 5.0
# ----------dự đoán cho dòng thứ 1117 là 0
# ----------dự đoán cho dòng thứ 1118 là 4.0
# ----------dự đoán cho dòng thứ 1119 là 0
# ----------dự đoán cho dòng thứ 1120 là 5.0
# ----------dự đoán cho dòng thứ 1121 là 0
# ----------dự đoán cho dòng thứ 1122 là 5.0
# ----------dự đoán cho dòng thứ 1123 là 5.0
# ----------dự đoán cho dòng thứ 1124 là 0
# ----------dự đoán cho dòng thứ 1125 là 4.9655172413793105
# ----------dự đoán cho dòng thứ 1126 là 4.5
# ----------dự đoán cho dòng thứ 1127 là 5.0
# ----------dự đoán cho dòng thứ 1128 là 5.0
# ----------dự đoán cho dòng thứ 1129 là 5.0
# ----------dự đoán cho dòng thứ 1130 là 5.0
# ----------dự đoán cho dòng thứ 1131 là 0
# ----------dự đoán cho dòng thứ 1132 là 0
# ----------dự đoán cho dòng thứ 1133 là 5.0
# ----------dự đoán cho dòng thứ 1134 là 5.0
# ----------dự đoán cho dòng thứ 1135 là 5.0
# ----------dự đoán cho dòng thứ 1136 là 5.0
# ----------dự đoán cho dòng thứ 1137 là 0
# ----------dự đoán cho dòng thứ 1138 là 5.0
# ----------dự đoán cho dòng thứ 1139 là 4.964285714285714
# ----------dự đoán cho dòng thứ 1140 là 0
# ----------dự đoán cho dòng thứ 1141 là 0
# ----------dự đoán cho dòng thứ 1142 là 5.0
# ----------dự đoán cho dòng thứ 1143 là 5.0
# ----------dự đoán cho dòng thứ 1144 là 0
# ----------dự đoán cho dòng thứ 1145 là 5.0
# ----------dự đoán cho dòng thứ 1146 là 4.75
# ----------dự đoán cho dòng thứ 1147 là 4.904761904761905
# ----------dự đoán cho dòng thứ 1148 là 0
# ----------dự đoán cho dòng thứ 1149 là 5.0
# ----------dự đoán cho dòng thứ 1150 là 4.75
# ----------dự đoán cho dòng thứ 1151 là 5.0
# ----------dự đoán cho dòng thứ 1152 là 5.0
# ----------dự đoán cho dòng thứ 1153 là 5.0
# ----------dự đoán cho dòng thứ 1154 là 4.0
# ----------dự đoán cho dòng thứ 1155 là 0
# ----------dự đoán cho dòng thứ 1156 là 0
# ----------dự đoán cho dòng thứ 1157 là 4.5
# ----------dự đoán cho dòng thứ 1158 là 5.0
# ----------dự đoán cho dòng thứ 1159 là 4.904645476772616
# ----------dự đoán cho dòng thứ 1160 là 5.0
# ----------dự đoán cho dòng thứ 1161 là 5.0
# ----------dự đoán cho dòng thứ 1162 là 5.0
# ----------dự đoán cho dòng thứ 1163 là 5.0
# ----------dự đoán cho dòng thứ 1164 là 0
# ----------dự đoán cho dòng thứ 1165 là 0
# ----------dự đoán cho dòng thứ 1166 là 5.0
# ----------dự đoán cho dòng thứ 1167 là 4.0
# ----------dự đoán cho dòng thứ 1168 là 0
# ----------dự đoán cho dòng thứ 1169 là 0
# ----------dự đoán cho dòng thứ 1170 là 0
# ----------dự đoán cho dòng thứ 1171 là 5.0
# ----------dự đoán cho dòng thứ 1172 là 0
# ----------dự đoán cho dòng thứ 1173 là 0
# ----------dự đoán cho dòng thứ 1174 là 5.0
# ----------dự đoán cho dòng thứ 1175 là 5.0
# ----------dự đoán cho dòng thứ 1176 là 5.0
# ----------dự đoán cho dòng thứ 1177 là 5.0
# ----------dự đoán cho dòng thứ 1178 là 5.0
# ----------dự đoán cho dòng thứ 1179 là 5.0
# ----------dự đoán cho dòng thứ 1180 là 5.0
# ----------dự đoán cho dòng thứ 1181 là 5.0
# ----------dự đoán cho dòng thứ 1182 là 5.0
# ----------dự đoán cho dòng thứ 1183 là 5.0
# ----------dự đoán cho dòng thứ 1184 là 0
# ----------dự đoán cho dòng thứ 1185 là 0
# ----------dự đoán cho dòng thứ 1186 là 5.0
# ----------dự đoán cho dòng thứ 1187 là 0
# ----------dự đoán cho dòng thứ 1188 là 0
# ----------dự đoán cho dòng thứ 1189 là 0
# ----------dự đoán cho dòng thứ 1190 là 0
# ----------dự đoán cho dòng thứ 1191 là 5.0
# ----------dự đoán cho dòng thứ 1192 là 0
# ----------dự đoán cho dòng thứ 1193 là 4.714285714285714
# ----------dự đoán cho dòng thứ 1194 là 5.0
# ----------dự đoán cho dòng thứ 1195 là 0
# ----------dự đoán cho dòng thứ 1196 là 5.0
# ----------dự đoán cho dòng thứ 1197 là 3.0
# ----------dự đoán cho dòng thứ 1198 là 5.0
# ----------dự đoán cho dòng thứ 1199 là 0
# ----------dự đoán cho dòng thứ 1200 là 0
# ----------dự đoán cho dòng thứ 1201 là 0
# ----------dự đoán cho dòng thứ 1202 là 0
# ----------dự đoán cho dòng thứ 1203 là 0
# ----------dự đoán cho dòng thứ 1204 là 5.0
# ----------dự đoán cho dòng thứ 1205 là 4.5
# ----------dự đoán cho dòng thứ 1206 là 0
# ----------dự đoán cho dòng thứ 1207 là 0
# ----------dự đoán cho dòng thứ 1208 là 0
# ----------dự đoán cho dòng thứ 1209 là 0
# ----------dự đoán cho dòng thứ 1210 là 0
# ----------dự đoán cho dòng thứ 1211 là 0
# ----------dự đoán cho dòng thứ 1212 là 0
# ----------dự đoán cho dòng thứ 1213 là 5.0
# ----------dự đoán cho dòng thứ 1214 là 0
# ----------dự đoán cho dòng thứ 1215 là 0
# ----------dự đoán cho dòng thứ 1216 là 5.0
# ----------dự đoán cho dòng thứ 1217 là 0
# ----------dự đoán cho dòng thứ 1218 là 4.75
# ----------dự đoán cho dòng thứ 1219 là 0
# ----------dự đoán cho dòng thứ 1220 là 5.0
# ----------dự đoán cho dòng thứ 1221 là 4.625
# ----------dự đoán cho dòng thứ 1222 là 5.0
# ----------dự đoán cho dòng thứ 1223 là 0
# ----------dự đoán cho dòng thứ 1224 là 0
# ----------dự đoán cho dòng thứ 1225 là 4.5
# ----------dự đoán cho dòng thứ 1226 là 0
# ----------dự đoán cho dòng thứ 1227 là 4.222222222222222
# ----------dự đoán cho dòng thứ 1228 là 0
# ----------dự đoán cho dòng thứ 1229 là 0
# ----------dự đoán cho dòng thứ 1230 là 5.0
# ----------dự đoán cho dòng thứ 1231 là 5.0
# ----------dự đoán cho dòng thứ 1232 là 4.625
# ----------dự đoán cho dòng thứ 1233 là 5.0
# ----------dự đoán cho dòng thứ 1234 là 4.322916666666667
# ----------dự đoán cho dòng thứ 1235 là 5.0
# ----------dự đoán cho dòng thứ 1236 là 0
# ----------dự đoán cho dòng thứ 1237 là 5.0
# ----------dự đoán cho dòng thứ 1238 là 5.0
# ----------dự đoán cho dòng thứ 1239 là 5.0
# ----------dự đoán cho dòng thứ 1240 là 0
# ----------dự đoán cho dòng thứ 1241 là 0
# ----------dự đoán cho dòng thứ 1242 là 0
# ----------dự đoán cho dòng thứ 1243 là 5.0
# ----------dự đoán cho dòng thứ 1244 là 0
# ----------dự đoán cho dòng thứ 1245 là 5.0
# ----------dự đoán cho dòng thứ 1246 là 5.0
# ----------dự đoán cho dòng thứ 1247 là 5.0
# ----------dự đoán cho dòng thứ 1248 là 5.0
# ----------dự đoán cho dòng thứ 1249 là 0
# ----------dự đoán cho dòng thứ 1250 là 0
# ----------dự đoán cho dòng thứ 1251 là 0
# ----------dự đoán cho dòng thứ 1252 là 0
# ----------dự đoán cho dòng thứ 1253 là 0
# ----------dự đoán cho dòng thứ 1254 là 5.0
# ----------dự đoán cho dòng thứ 1255 là 0
# ----------dự đoán cho dòng thứ 1256 là 5.0
# ----------dự đoán cho dòng thứ 1257 là 5.0
# ----------dự đoán cho dòng thứ 1258 là 0
# ----------dự đoán cho dòng thứ 1259 là 0
# ----------dự đoán cho dòng thứ 1260 là 5.0
# ----------dự đoán cho dòng thứ 1261 là 5.0
# ----------dự đoán cho dòng thứ 1262 là 0
# ----------dự đoán cho dòng thứ 1263 là 5.0
# ----------dự đoán cho dòng thứ 1264 là 4.666666666666667
# ----------dự đoán cho dòng thứ 1265 là 0
# ----------dự đoán cho dòng thứ 1266 là 5.0
# ----------dự đoán cho dòng thứ 1267 là 5.0
# ----------dự đoán cho dòng thứ 1268 là 0
# ----------dự đoán cho dòng thứ 1269 là 4.6
# ----------dự đoán cho dòng thứ 1270 là 5.0
# ----------dự đoán cho dòng thứ 1271 là 0
# ----------dự đoán cho dòng thứ 1272 là 0
# ----------dự đoán cho dòng thứ 1273 là 5.0
# ----------dự đoán cho dòng thứ 1274 là 5.0
# ----------dự đoán cho dòng thứ 1275 là 5.0
# ----------dự đoán cho dòng thứ 1276 là 5.0
# ----------dự đoán cho dòng thứ 1277 là 0
# ----------dự đoán cho dòng thứ 1278 là 0
# ----------dự đoán cho dòng thứ 1279 là 0
# ----------dự đoán cho dòng thứ 1280 là 5.0
# ----------dự đoán cho dòng thứ 1281 là 5.0
# ----------dự đoán cho dòng thứ 1282 là 5.0
# ----------dự đoán cho dòng thứ 1283 là 0
# ----------dự đoán cho dòng thứ 1284 là 0
# ----------dự đoán cho dòng thứ 1285 là 0
# ----------dự đoán cho dòng thứ 1286 là 5.0
# ----------dự đoán cho dòng thứ 1287 là 5.0
# ----------dự đoán cho dòng thứ 1288 là 0
# ----------dự đoán cho dòng thứ 1289 là 5.0
# ----------dự đoán cho dòng thứ 1290 là 5.0
# ----------dự đoán cho dòng thứ 1291 là 4.980036297640654
# ----------dự đoán cho dòng thứ 1292 là 5.0
# ----------dự đoán cho dòng thứ 1293 là 5.0
# ----------dự đoán cho dòng thứ 1294 là 0
# ----------dự đoán cho dòng thứ 1295 là 0
# ----------dự đoán cho dòng thứ 1296 là 5.0
# ----------dự đoán cho dòng thứ 1297 là 0
# ----------dự đoán cho dòng thứ 1298 là 4.828402366863905
# ----------dự đoán cho dòng thứ 1299 là 5.0
# ----------dự đoán cho dòng thứ 1300 là 5.0
# ----------dự đoán cho dòng thứ 1301 là 0
# ----------dự đoán cho dòng thứ 1302 là 0
# ----------dự đoán cho dòng thứ 1303 là 0
# ----------dự đoán cho dòng thứ 1304 là 0
# ----------dự đoán cho dòng thứ 1305 là 5.0
# ----------dự đoán cho dòng thứ 1306 là 5.0
# ----------dự đoán cho dòng thứ 1307 là 5.0
# ----------dự đoán cho dòng thứ 1308 là 0
# ----------dự đoán cho dòng thứ 1309 là 0
# ----------dự đoán cho dòng thứ 1310 là 5.0
# ----------dự đoán cho dòng thứ 1311 là 4.990196078431373
# ----------dự đoán cho dòng thứ 1312 là 0
# ----------dự đoán cho dòng thứ 1313 là 5.0
# ----------dự đoán cho dòng thứ 1314 là 0
# ----------dự đoán cho dòng thứ 1315 là 5.0
# ----------dự đoán cho dòng thứ 1316 là 4.5
# ----------dự đoán cho dòng thứ 1317 là 0
# ----------dự đoán cho dòng thứ 1318 là 5.0
# ----------dự đoán cho dòng thứ 1319 là 5.0
# ----------dự đoán cho dòng thứ 1320 là 5.0
# ----------dự đoán cho dòng thứ 1321 là 5.0
# ----------dự đoán cho dòng thứ 1322 là 5.0
# ----------dự đoán cho dòng thứ 1323 là 4.94
# ----------dự đoán cho dòng thứ 1324 là 5.0
# ----------dự đoán cho dòng thứ 1325 là 0
# ----------dự đoán cho dòng thứ 1326 là 5.0
# ----------dự đoán cho dòng thứ 1327 là 5.0
# ----------dự đoán cho dòng thứ 1328 là 5.0
# ----------dự đoán cho dòng thứ 1329 là 5.0
# ----------dự đoán cho dòng thứ 1330 là 5.0
# ----------dự đoán cho dòng thứ 1331 là 4.0
# ----------dự đoán cho dòng thứ 1332 là 0
# ----------dự đoán cho dòng thứ 1333 là 5.0
# ----------dự đoán cho dòng thứ 1334 là 4.0
# ----------dự đoán cho dòng thứ 1335 là 0
# ----------dự đoán cho dòng thứ 1336 là 0
# ----------dự đoán cho dòng thứ 1337 là 5.0
# ----------dự đoán cho dòng thứ 1338 là 0
# ----------dự đoán cho dòng thứ 1339 là 5.0
# ----------dự đoán cho dòng thứ 1340 là 5.0
# ----------dự đoán cho dòng thứ 1341 là 0
# ----------dự đoán cho dòng thứ 1342 là 0
# ----------dự đoán cho dòng thứ 1343 là 0
# ----------dự đoán cho dòng thứ 1344 là 5.0
# ----------dự đoán cho dòng thứ 1345 là 0
# ----------dự đoán cho dòng thứ 1346 là 0
# ----------dự đoán cho dòng thứ 1347 là 5.0
# ----------dự đoán cho dòng thứ 1348 là 5.0
# ----------dự đoán cho dòng thứ 1349 là 4.25
# ----------dự đoán cho dòng thứ 1350 là 5.0
# ----------dự đoán cho dòng thứ 1351 là 5.0
# ----------dự đoán cho dòng thứ 1352 là 0
# ----------dự đoán cho dòng thứ 1353 là 5.0
# ----------dự đoán cho dòng thứ 1354 là 5.0
# ----------dự đoán cho dòng thứ 1355 là 0
# ----------dự đoán cho dòng thứ 1356 là 0
# ----------dự đoán cho dòng thứ 1357 là 0
# ----------dự đoán cho dòng thứ 1358 là 0
# ----------dự đoán cho dòng thứ 1359 là 4.0
# ----------dự đoán cho dòng thứ 1360 là 5.0
# ----------dự đoán cho dòng thứ 1361 là 3.6666666666666665
# ----------dự đoán cho dòng thứ 1362 là 5.0
# ----------dự đoán cho dòng thứ 1363 là 5.0
# ----------dự đoán cho dòng thứ 1364 là 5.0
# ----------dự đoán cho dòng thứ 1365 là 5.0
# ----------dự đoán cho dòng thứ 1366 là 5.0
# ----------dự đoán cho dòng thứ 1367 là 5.0
# ----------dự đoán cho dòng thứ 1368 là 5.0
# ----------dự đoán cho dòng thứ 1369 là 4.666666666666667
# ----------dự đoán cho dòng thứ 1370 là 0
# ----------dự đoán cho dòng thứ 1371 là 0
# ----------dự đoán cho dòng thứ 1372 là 5.0
# ----------dự đoán cho dòng thứ 1373 là 5.0
# ----------dự đoán cho dòng thứ 1374 là 0
# ----------dự đoán cho dòng thứ 1375 là 0
# ----------dự đoán cho dòng thứ 1376 là 5.0
# ----------dự đoán cho dòng thứ 1377 là 5.0
# ----------dự đoán cho dòng thứ 1378 là 5.0
# ----------dự đoán cho dòng thứ 1379 là 0
# ----------dự đoán cho dòng thứ 1380 là 0
# ----------dự đoán cho dòng thứ 1381 là 5.0
# ----------dự đoán cho dòng thứ 1382 là 5.0
# ----------dự đoán cho dòng thứ 1383 là 0
# ----------dự đoán cho dòng thứ 1384 là 5.0
# ----------dự đoán cho dòng thứ 1385 là 0
# ----------dự đoán cho dòng thứ 1386 là 5.0
# ----------dự đoán cho dòng thứ 1387 là 5.0
# ----------dự đoán cho dòng thứ 1388 là 5.0
# ----------dự đoán cho dòng thứ 1389 là 4.666666666666667
# ----------dự đoán cho dòng thứ 1390 là 0
# ----------dự đoán cho dòng thứ 1391 là 5.0
# ----------dự đoán cho dòng thứ 1392 là 5.0
# ----------dự đoán cho dòng thứ 1393 là 5.0
# ----------dự đoán cho dòng thứ 1394 là 5.0
# ----------dự đoán cho dòng thứ 1395 là 4.0
# ----------dự đoán cho dòng thứ 1396 là 0
# ----------dự đoán cho dòng thứ 1397 là 5.0
# ----------dự đoán cho dòng thứ 1398 là 0
# ----------dự đoán cho dòng thứ 1399 là 0
# ----------dự đoán cho dòng thứ 1400 là 4.125
# ----------dự đoán cho dòng thứ 1401 là 5.0
# ----------dự đoán cho dòng thứ 1402 là 5.0
# ----------dự đoán cho dòng thứ 1403 là 0
# ----------dự đoán cho dòng thứ 1404 là 0
# ----------dự đoán cho dòng thứ 1405 là 5.0
# ----------dự đoán cho dòng thứ 1406 là 5.0
# ----------dự đoán cho dòng thứ 1407 là 5.0
# ----------dự đoán cho dòng thứ 1408 là 0
# ----------dự đoán cho dòng thứ 1409 là 5.0
# ----------dự đoán cho dòng thứ 1410 là 0
# ----------dự đoán cho dòng thứ 1411 là 5.0
# ----------dự đoán cho dòng thứ 1412 là 5.0
# ----------dự đoán cho dòng thứ 1413 là 5.0
# ----------dự đoán cho dòng thứ 1414 là 0
# ----------dự đoán cho dòng thứ 1415 là 4.492307692307692
# ----------dự đoán cho dòng thứ 1416 là 5.0
# ----------dự đoán cho dòng thứ 1417 là 0
# ----------dự đoán cho dòng thứ 1418 là 1.0
# ----------dự đoán cho dòng thứ 1419 là 5.0
# ----------dự đoán cho dòng thứ 1420 là 5.0
# ----------dự đoán cho dòng thứ 1421 là 0
# ----------dự đoán cho dòng thứ 1422 là 0
# Tổng thời gian dự đoán : 18952.814144849777

# %%
import csv
X_test_pred_rating1= pd.DataFrame(data=X_test_pred_rating)
#X_test_pred_rating1 = X_test_pred_rating
X_test_pred_rating1.to_csv('/content/drive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/Pre-TBDG-Pearson.csv',header=True, index = None)

# %%
X_test_pred_rating = pd.read_csv('/content/drive/MyDrive/recomment_system/Do_an/Collaborative_Filtering/CF_Item_Based/Pre-TBDG-Pearson.csv')

# %%
X_test_pred_rating = list(np.where(np.isnan(X_test_pred_rating), 0, X_test_pred_rating))

X_test_pred_rating_select = []
X_test_true_rating_select = []

for i in range(len(X_test_pred_rating)):
    if (X_test_pred_rating[i] != 0):
        X_test_pred_rating_select.append(X_test_pred_rating[i])
        X_test_true_rating_select.append(test['rating'].tolist()[i])
        X_test_pred_rating_select_round = [np.round(num) for num in X_test_pred_rating_select]

mse = mean_squared_error(X_test_true_rating_select, X_test_pred_rating_select)
rmse = math.sqrt(mse)
mae = mean_absolute_error(X_test_true_rating_select, X_test_pred_rating_select)

X_test_true_rating_select.sort(reverse = True)
max = X_test_true_rating_select[0]
min = X_test_true_rating_select[len(X_test_true_rating_select)-1]
nmae = mae/(max-min)
print('---------------------------------')
print('Đánh giá trên độ đo MSE:', mse)
print('Đánh giá trên độ đo RMSE:', rmse)
print('Đánh giá trên độ đo MAE:', mae)
print('Đánh giá trên độ đo NMAE:', nmae)
# Out:
# ---------------------------------
# Đánh giá trên độ đo MSE: 0.36162898718654035
# Đánh giá trên độ đo RMSE: 0.6013559571389814
# Đánh giá trên độ đo MAE: 0.23908786388122605
# Đánh giá trên độ đo NMAE: 0.05977196597030651
